# %%
# Import libraries
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Downloading and Extracting Tickers for Information Technology and Utilities Sector in S&P 500

# %%
# Download the S&P 500 company data from Wikipedia
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Filter the DataFrame to only include companies in the Information Technology sector
IT_sp500_df = sp500_df[sp500_df['GICS Sector'] == 'Information Technology']

# Sort the filtered DataFrame by ticker symbol in alphabetical order
sorted_IT_sp500_df = IT_sp500_df.sort_values('Symbol')

# Extract the list of ticker symbols from the sorted DataFrame
IT_sp500_tickers = sorted_IT_sp500_df['Symbol'].tolist()

# Print the list of ticker symbols and number of stocks in Information Technology sector
print(IT_sp500_tickers)
len(IT_sp500_tickers)
# Out:
# ['AAPL', 'ACN', 'ADBE', 'ADI', 'ADSK', 'AKAM', 'AMAT', 'AMD', 'ANET', 'ANSS', 'APH', 'AVGO', 'CDAY', 'CDNS', 'CDW', 'CRM', 'CSCO', 'CTSH', 'DXC', 'ENPH', 'EPAM', 'FFIV', 'FICO', 'FSLR', 'FTNT', 'GEN', 'GLW', 'HPE', 'HPQ', 'IBM', 'INTC', 'INTU', 'IT', 'JNPR', 'KEYS', 'KLAC', 'LRCX', 'MCHP', 'MPWR', 'MSFT', 'MSI', 'MU', 'NOW', 'NTAP', 'NVDA', 'NXPI', 'ON', 'ORCL', 'PAYC', 'PTC', 'QCOM', 'QRVO', 'ROP', 'SEDG', 'SNPS', 'STX', 'SWKS', 'TDY', 'TEL', 'TER', 'TRMB', 'TXN', 'TYL', 'VRSN', 'WDC', 'ZBRA']
# 66

# %%
# Download the S&P 500 company data from Wikipedia
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Filter the DataFrame to only include companies in the Utilities sector
utilities_sp500_df = sp500_df[sp500_df['GICS Sector'] == 'Utilities']

# Sort the filtered DataFrame by ticker symbol in alphabetical order
sorted_utilities_sp500_df = utilities_sp500_df.sort_values('Symbol')

# Extract the list of ticker symbols from the sorted DataFrame
utilities_sp500_tickers = sorted_utilities_sp500_df['Symbol'].tolist()

# Print the list of ticker symbols and number of stocks in Utilities sector
print(utilities_sp500_tickers)
len(utilities_sp500_tickers)
# Out:
# ['AEE', 'AEP', 'AES', 'ATO', 'AWK', 'CEG', 'CMS', 'CNP', 'D', 'DTE', 'DUK', 'ED', 'EIX', 'ES', 'ETR', 'EVRG', 'EXC', 'FE', 'LNT', 'NEE', 'NI', 'NRG', 'PCG', 'PEG', 'PNW', 'PPL', 'SO', 'SRE', 'WEC', 'XEL']
# 30

# %% [markdown]
# # Downloading Stock Price Data and Calculating Daily Log-Returns,Visualization

# %% [markdown]
# # Information Technology Sector

# %%
#Import stock prices from Yahoo Finance:
IT_adj_close = yf.download(IT_sp500_tickers, start = "2022-01-01", end = "2022-12-31")["Adj Close"]
IT_adj_close
# Out:
# [*********************100%***********************]  66 of 66 completed
#                   AAPL         ACN        ADBE         ADI        ADSK  \
# Date
# 2022-01-03  180.683853  398.527893  564.369995  173.052872  283.720001
# 2022-01-04  178.390701  395.679932  554.000000  171.489883  278.190002
# 2022-01-05  173.645523  388.711761  514.429993  168.842560  264.320007
# 2022-01-06  170.746811  369.940674  514.119995  169.379837  264.109985
# 2022-01-07  170.915558  362.845276  510.700012  164.935074  262.320007
# ...                ...         ...         ...         ...         ...
# 2022-12-23  131.658981  263.969421  338.450012  163.081024  188.160004
# 2022-12-27  129.831772  263.195648  335.089996  161.448624  186.289993
# 2022-12-28  125.847855  261.023102  328.329987  159.537521  181.899994
# 2022-12-29  129.412415  266.241180  337.579987  163.220383  188.119995
# 2022-12-30  129.731918  264.713440  336.529999  163.270157  186.869995
#
# ...

# %%
#Calculate the daily log-returns for each stock
IT_log_returns = np.log(IT_adj_close / IT_adj_close.shift(1))
print(IT_log_returns)
# Out:
#                 AAPL       ACN      ADBE       ADI      ADSK      AKAM  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.012773 -0.007172 -0.018545 -0.009073 -0.019683 -0.004777
# 2022-01-05 -0.026960 -0.017768 -0.074105 -0.015558 -0.051144 -0.012649
# 2022-01-06 -0.016834 -0.049495 -0.000603  0.003177 -0.000795 -0.031671
# 2022-01-07  0.000988 -0.019366 -0.006674 -0.026592 -0.006800 -0.012049
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23 -0.002802  0.005011  0.005719  0.000549  0.000319  0.005305
# 2022-12-27 -0.013976 -0.002936 -0.009977 -0.010060 -0.009988  0.004080
# 2022-12-28 -0.031166 -0.008289 -0.020380 -0.011908 -0.023848  0.000000
# 2022-12-29  0.027931  0.019794  0.027783  0.022822  0.033623  0.014269
# 2022-12-30  0.002466 -0.005755 -0.003115  0.000305 -0.006667 -0.004734
#
#                 AMAT       AMD      ANET      ANSS  ...      SWKS       TDY  \
# ...

# %%
#Calculate annualized log-return
IT_annualized_returns = ((1 + IT_log_returns.mean()) ** 252 - 1)*100

#Create a DataFrame
IT_df = pd.DataFrame({'Annualized Returns': IT_annualized_returns})

# Round values to two decimal places
IT_df['Annualized Returns'] = IT_df['Annualized Returns'].round(2)

#Sort Data
IT_df_sorted = IT_df.sort_values(by='Annualized Returns', ascending=False)

print(IT_df_sorted)
# Out:
#       Annualized Returns
# FSLR               69.72
# ENPH               44.03
# FICO               35.38
# IBM                 8.77
# IT                  4.44
# ...                  ...
# NVDA              -51.77
# STX               -51.82
# WDC               -52.48
# ZBRA              -56.43
# AMD               -57.24
#
# [66 rows x 1 columns]

# %%
# Visualize the annualized returns using a bar chart
IT_df_sorted.plot(kind='bar', figsize=(20,10))
plt.title('Performance of Information Technology Sector', fontsize=18)
plt.ylabel('Annualized Returns (%)', fontsize=14)
plt.xlabel('Tickers', fontsize=14)
plt.show()

# %% [markdown]
# # Utilities Sector

# %%
#Import stock prices from Yahoo Finance:
utilities_adj_close = yf.download(utilities_sp500_tickers, start = "2022-01-01", end = "2022-12-31")["Adj Close"]
utilities_adj_close
# Out:
# [*********************100%***********************]  30 of 30 completed
#                   AEE        AEP        AES         ATO         AWK  \
# Date
# 2022-01-03  85.643913  84.885902  23.563202  101.810730  180.237473
# 2022-01-04  85.189499  84.924225  23.630857  103.022652  175.617493
# 2022-01-05  85.402206  85.709755  22.548382  103.352295  174.325485
# 2022-01-06  84.986443  85.431946  22.461393  102.547569  171.584824
# 2022-01-07  85.315186  86.983879  22.326088  102.082199  169.822952
# ...               ...        ...        ...         ...         ...
# 2022-12-23  88.852966  94.811234  28.500004  114.371452  152.380020
# 2022-12-27  89.597290  95.405724  28.639126  114.848419  153.634750
# 2022-12-28  88.704094  94.484268  28.142263  114.341644  152.479599
# 2022-12-29  89.329338  95.128296  28.629187  113.765312  154.132660
# 2022-12-30  88.247574  94.078026  28.579502  111.360634  151.782532
#
# ...

# %%
#Calculate the daily log-returns for each stock
utilities_log_returns = np.log(utilities_adj_close / utilities_adj_close.shift(1))
print(utilities_log_returns)
# Out:
#                  AEE       AEP       AES       ATO       AWK       CEG  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.005320  0.000451  0.002867  0.011833 -0.025967       NaN
# 2022-01-05  0.002494  0.009207 -0.046890  0.003195 -0.007384       NaN
# 2022-01-06 -0.004880 -0.003247 -0.003865 -0.007817 -0.015846       NaN
# 2022-01-07  0.003861  0.018003 -0.006042 -0.004548 -0.010321       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.013154  0.012831  0.012985  0.009340  0.007149  0.008097
# 2022-12-27  0.008342  0.006251  0.004870  0.004162  0.008201 -0.004554
# 2022-12-28 -0.010019 -0.009705 -0.017501 -0.004422 -0.007547 -0.011822
# 2022-12-29  0.007024  0.006793  0.017154 -0.005053  0.010783  0.001846
# 2022-12-30 -0.012184 -0.011102 -0.001737 -0.021364 -0.015365 -0.006475
#
#                  CMS       CNP         D       DTE  ...        NI       NRG  \
# ...

# %%
#Calculate annualized log-return
utilities_annualized_returns = ((1 + utilities_log_returns.mean()) ** 252 - 1)*100

#Create a DataFrame
utilities_df = pd.DataFrame({'Annualized Returns': utilities_annualized_returns})

# Round values to two decimal places
utilities_df['Annualized Returns'] = utilities_df['Annualized Returns'].round(2)

#Sort Data
utilities_df_sorted = utilities_df.sort_values(by='Annualized Returns', ascending=False)

print (utilities_df_sorted)
# Out:
#       Annualized Returns
# CEG               115.25
# PCG                33.45
# AES                21.47
# SRE                20.74
# ED                 16.04
# PNW                14.42
# CNP                11.25
# AEP                10.92
# EXC                 9.68
# ATO                 9.46
# SO                  8.97
# XEL                 6.12
# FE                  5.72
# ETR                 4.75
# DUK                 3.44
# AEE                 3.06
# NI                  3.03
# DTE                 1.55
# CMS                 0.71
# WEC                 0.57
# PPL                 0.09
# EIX                -1.52
# ES                 -3.11
# EVRG               -4.30
# PEG                -4.31
# LNT                -6.55
# NEE                -6.90
# AWK               -15.91
# D                 -19.04
# NRG               -23.43

# %%
# Visualize the annualized returns using a bar chart
utilities_df_sorted.plot(kind='bar', figsize=(20,10))
plt.title('Utilities Sector', fontsize=18)
plt.ylabel('Annualized Returns (%)', fontsize=14)
plt.xlabel('Tickers', fontsize=14)
plt.show()

# %% [markdown]
# # Descriptive Statistics for Top 3 Stocks Daily Log Returns

# %% [markdown]
# # Information Technology

# %%
IT_log_returns.reindex(columns=IT_df_sorted.head(3).index.tolist()).describe()
# Out:
#              FSLR        ENPH        FICO
# count  250.000000  250.000000  250.000000
# mean     0.002101    0.001449    0.001203
# std      0.032390    0.045527    0.030517
# min     -0.090704   -0.131317   -0.093859
# 25%     -0.017802   -0.026020   -0.013536
# 50%      0.000997    0.002318    0.000516
# 75%      0.020475    0.025933    0.014992
# max      0.142319    0.164620    0.270786

# %% [markdown]
# # Utilities

# %%
utilities_log_returns.reindex(columns=utilities_df_sorted.head(3).index.tolist()).describe()
# Out:
#               CEG         PCG         AES
# count  239.000000  250.000000  250.000000
# mean     0.003047    0.001146    0.000772
# std      0.029561    0.022520    0.022085
# min     -0.084657   -0.076863   -0.079340
# 25%     -0.015285   -0.012364   -0.012750
# 50%      0.001846    0.001639    0.000000
# 75%      0.020051    0.018208    0.013730
# max      0.151136    0.079162    0.090608

# %% [markdown]
# # Descriptivie Statistics for Each Sectors Annualized Returns

# %%
IT_df_sorted.describe()
# Out:
#        Annualized Returns
# count           66.000000
# mean           -23.201364
# std             23.376205
# min            -57.240000
# 25%            -39.765000
# 50%            -27.495000
# 75%            -11.290000
# max             69.720000

# %%
utilities_df_sorted.describe()
# Out:
#        Annualized Returns
# count           30.000000
# mean             7.187333
# std             23.597232
# min            -23.430000
# 25%             -2.712500
# 50%              3.250000
# 75%             10.610000
# max            115.250000

# %% [markdown]
# # Comparision Between S&P500 and Top 3 Stocks

# %%
#Import S&P500 Data
SP500 = ('^GSPC')
SP500 = yf.download(SP500, start = "2022-01-01", end = "2022-12-31")["Adj Close"]

#Calculate the daily log-returns for S&P500
SP500_returns = np.log(SP500 / SP500.shift(1))

#Calculate annualized log-return
annualized_returns_SP500 = ((1 + SP500_returns.mean()) ** 252 - 1)*100
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Information Technology Sector Top 3 - FSLR, ENPH, FICO

# %%
IT_top_stocks = IT_df_sorted.head(3)

plt.figure(figsize=(20,10))
plt.bar(IT_top_stocks.index, IT_top_stocks['Annualized Returns'], label='Top 3 Stocks')
plt.bar('SP500', annualized_returns_SP500, label='S&P 500')
plt.xticks(rotation=90, fontsize=12)
plt.yticks(range(-100, int(IT_top_stocks['Annualized Returns'].max())+5, 5))
plt.ylabel('Annualized returns (%)', fontsize=16)
plt.xlabel('Tickers', fontsize=14)
plt.title('Top Performing IT Stocks VS S&P500', fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # Utilities Sector Top 3 - CEG, PCG, AES

# %%
utilities_top_stocks = utilities_df_sorted.head(3)

plt.figure(figsize=(20,10))
plt.bar(utilities_top_stocks.index, utilities_top_stocks['Annualized Returns'], label='Top 3 Stocks')
plt.bar('SP500', annualized_returns_SP500, label='S&P 500')
plt.xticks(rotation=90, fontsize=12)
plt.yticks(range(-100, int(utilities_top_stocks['Annualized Returns'].max())+5, 5))
plt.ylabel('Annualized returns (%)', fontsize=16)
plt.xlabel('Tickers', fontsize=14)
plt.title('Top Performing Utilities Stocks VS S&P500', fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # Comparision Between S&P500 and Each Sectors

# %% [markdown]
# # Information Technology

# %%
# Calculate the daily log-returns for financials sector ticker XLK

XLK_adj_close = yf.download("XLK", start = "2022-01-01", end = "2022-12-31")["Adj Close"]

XLK_log_returns = np.log(XLK_adj_close/XLK_adj_close.shift(1))
print(XLK_log_returns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-01-03         NaN
# 2022-01-04   -0.010654
# 2022-01-05   -0.031232
# 2022-01-06   -0.005063
# 2022-01-07   -0.009238
#                 ...
# 2022-12-23    0.001044
# 2022-12-27   -0.009515
# 2022-12-28   -0.016255
# 2022-12-29    0.025851
# 2022-12-30   -0.001365
# Name: Adj Close, Length: 251, dtype: float64

# %%
# Calculate annualized log-return
XLK_annualized_returns = ((1 + XLK_log_returns.mean()) ** 252 - 1) * 100
print(XLK_annualized_returns)
# Out:
# -28.61292548592378

# %%
plt.figure(figsize=(20,10))
plt.bar("XLK", XLK_annualized_returns, label="XLK")
plt.bar("S&P 500", annualized_returns_SP500, label="S&P 500")
plt.xticks(rotation=90, fontsize=12)
plt.ylabel("Annualized returns (%)", fontsize=16)
plt.xlabel("Tickers", fontsize=14)
plt.title("XLK VS S&P500", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # Utilities Sector

# %%
# Calculate the daily log-returns for financials sector ticker XLU

XLU_adj_close = yf.download("XLU", start = "2022-01-01", end = "2022-12-31")["Adj Close"]

XLU_log_returns = np.log(XLU_adj_close/XLU_adj_close.shift(1))
print(XLU_log_returns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-01-03         NaN
# 2022-01-04   -0.003109
# 2022-01-05   -0.000566
# 2022-01-06   -0.010392
# 2022-01-07    0.007556
#                 ...
# 2022-12-23    0.010206
# 2022-12-27    0.006186
# 2022-12-28   -0.009576
# 2022-12-29    0.007191
# 2022-12-30   -0.009599
# Name: Adj Close, Length: 251, dtype: float64

# %%
# Calculate annualized log-return
XLU_annualized_returns = ((1 + XLU_log_returns.mean()) ** 252 - 1) * 100
print(XLU_annualized_returns)
# Out:
# 2.479025816601599

# %%
plt.figure(figsize=(20,10))
plt.bar("XLU", XLU_annualized_returns, label="XLU")
plt.bar("S&P 500", annualized_returns_SP500, label="S&P 500")
plt.xticks(rotation=90, fontsize=12)
plt.ylabel("Annualized returns (%)", fontsize=16)
plt.xlabel("Tickers", fontsize=14)
plt.title("XLU VS S&P500", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plot
import numpy as np

# %%
stock_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")

# %%
stock_df = stock_df[0]

# %%
stock_df
# Out:
#     Symbol              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota  1957-03-04
# 1                     Building Products     Milwaukee, Wisconsin  2017-07-26
# ...

# %%
#Getting all the tickers symbols within the healthcare sector 
healthcare = stock_df[stock_df["GICS Sector"] == "Health Care"]

#changing it to a list
healthcare_list = healthcare["Symbol"].tolist()

#Getting the price data from yahoo 
healthcare_adj_close = yf.download(healthcare_list, start = "2022-01-01", end = "2022-12-31")["Adj Close"]

#Calculating the daily log returns for each stock
log_returns = np.log(healthcare_adj_close / healthcare_adj_close.shift(1))
log_returns
# Out:
# [*********************100%***********************]  65 of 65 completed
#                    A      ABBV       ABC       ABT      ALGN      AMGN  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.034391 -0.001922 -0.009546 -0.023799 -0.038619  0.005060
# 2022-01-05 -0.017279  0.005239  0.008641 -0.004503 -0.074323 -0.011921
# 2022-01-06  0.003493 -0.004721 -0.015593 -0.000148 -0.019574  0.000133
# 2022-01-07 -0.026984 -0.002592  0.020261  0.003103 -0.037022  0.009371
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.001475 -0.001042  0.004362  0.001388  0.000884 -0.005064
# 2022-12-27  0.002142 -0.000675 -0.005958  0.003599  0.004507 -0.002010
# 2022-12-28 -0.009811 -0.004674 -0.009752 -0.006839 -0.014822 -0.007508
# 2022-12-29  0.020055  0.002032 -0.007858  0.022739  0.051060  0.006634
# 2022-12-30 -0.008086 -0.005861 -0.002050 -0.004725 -0.005862 -0.001978
#
# ...

# %%
#Calculate annuallog-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

#Creating a df
healthcare_df = pd.DataFrame({'Annualized Returns': annualized_returns})
healthcare_df["Annualized Returns"] = healthcare_df["Annualized Returns"].round(2)

healthcare_df_sorted = healthcare_df.sort_values(by = "Annualized Returns", ascending = False)


healthcare_df_sorted
# Out:
#       Annualized Returns
# CAH                53.00
# MCK                52.57
# MRK                49.40
# CI                 44.20
# LLY                36.79
# ...                  ...
# ILMN              -47.22
# WST               -47.41
# GEHC              -49.88
# CTLT              -64.21
# ALGN              -67.83
#
# [65 rows x 1 columns]

# %%
#Creating the data visualization for the annualized return
import matplotlib.pyplot as plot

healthcare_df_sorted.plot(kind = 'bar',figsize= (12,8), color = "teal")
plot.title("Annualized Returns for Healthcare Stocks", fontweight = 'bold')
plot.ylabel("Return(%)")
plot.xlabel("Stocks in the Healthcare Sector of the S&P 500")
plot.show()

# %%
#Doing the same thing I did for healthcare but now for consumer staples
#Getting all the tickers symbols within the healthcare sector 
consumer_staples = stock_df[stock_df["GICS Sector"] == "Consumer Staples"]

#changing it to a list
consumer_staples_list = consumer_staples["Symbol"].tolist()
consumer_staples_list[2] = "BF-B"

#Getting the price data from yahoo 
consumer_staples_adj_close = yf.download(consumer_staples_list, start = "2022-01-01", end = "2022-12-31")["Adj Close"]

#Calculating the daily log returns for each stock
cs_log_returns = np.log(consumer_staples_adj_close / consumer_staples_adj_close.shift(1))
cs_log_returns
# Out:
# [*********************100%***********************]  37 of 37 completed
#                  ADM      BF-B        BG       CAG       CHD        CL  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04  0.018389 -0.002237  0.008712  0.004102  0.001081  0.003304
# 2022-01-05 -0.007840  0.005863 -0.005942 -0.001463  0.007046  0.004116
# 2022-01-06  0.008851 -0.037146  0.022622 -0.018322  0.001656 -0.006593
# 2022-01-07  0.008487 -0.015723  0.009320  0.035739  0.008628 -0.002602
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.012014 -0.002559  0.018871  0.002062  0.002685  0.002142
# 2022-12-27  0.013541  0.003461  0.016238  0.004624 -0.001830  0.006149
# 2022-12-28 -0.024166 -0.015286 -0.010796 -0.009528 -0.012160 -0.014110
# 2022-12-29 -0.005355  0.008807  0.002910  0.003100  0.008123  0.006954
# 2022-12-30 -0.002904 -0.007131 -0.000201 -0.001807 -0.011961 -0.007334
#
# ...

# %%
#Calculating the annualized return for consumer staples

cs_annualized_returns = ((1 + cs_log_returns.mean()) ** 252 - 1)*100

#Creating a df
consumer_staples_df = pd.DataFrame({'Annualized Returns': cs_annualized_returns})
consumer_staples_df["Annualized Returns"] = consumer_staples_df["Annualized Returns"].round(2)

consumer_staples_df_sorted = consumer_staples_df.sort_values(by = "Annualized Returns", ascending = False)


consumer_staples_df_sorted
# Out:
#       Annualized Returns
# LW                 42.05
# ADM                39.70
# CPB                34.27
# GIS                28.56
# HSY                22.21
# SJM                19.36
# CAG                17.98
# KHC                17.54
# K                  14.01
# TAP                12.08
# PM                 11.55
# KO                 10.53
# BG                  8.94
# PEP                 7.29
# DG                  5.58
# MNST                5.21
# MDLZ                3.48
# MO                  3.14
# KR                  0.60
# DLTR                0.19
# WMT                -0.44
# KDP                -0.83
# SYY                -0.84
# KMB                -1.25
# CL                 -4.64
# PG                 -4.69
# HRL                -5.34
# STZ                -7.17
# BF-B               -7.30
# MKC               -12.02
# CLX               -17.40
# COST              -19.05
# CHD               -19.94
# WBA               -26.53
# TSN               -27.63
# EL                -32.56
# ...

# %%
#Creating the data visualization for the annualized return

consumer_staples_df_sorted.plot(kind = 'bar',figsize= (12,8), color = "teal")
plot.title("Annualized Returns for Consumer Staples Stocks", fontweight = 'bold')
plot.ylabel("Return(%)")
plot.xlabel("Stocks in the Consumer Staples Sector of the S&P 500")
plot.show()

# %% [markdown]
# Analyzing the top 3 performing stocks in healthcare

# %%
#Getting the top 3 performing stocks in healthcare

tickers = ["CAH","MCK","MRK"]

#geting price from yahoo
CAH = yf.download("CAH",start = "2022-01-01", end = "2022-12-31")["Adj Close"]

CAH_log_returns = np.log(CAH / CAH.shift(1))
print("Please see below for the statistic analysis for CAH:")
CAH_df = pd.DataFrame(CAH_log_returns)
CAH_stats = CAH_df.describe().rename(index={'mean':'Average','std':'Standard Deviation','25%':'25th Percentile','min':'Minimum','max':'Maximum','50%':'50th Percentile','75%':'75th Percentile'})
CAH_stats.drop(['count'], axis = 0, inplace = True )
CAH_stats

# CAH_annualized = ((1 + CAH_log_returns.mean()) ** 252 - 1)*100
# CAH_annualized = CAH_annualized.round(2)
# print("Annualized return for CAH:",CAH_annualized)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Please see below for the statistic analysis for CAH:
#                     Adj Close
# Average              0.001689
# Standard Deviation   0.017104
# Minimum             -0.061005
# 25th Percentile     -0.007636
# 50th Percentile      0.000873
# 75th Percentile      0.011276
# Maximum              0.061663

# %%
tickers = ["CAH","MCK","MRK"]

#geting price from yahoo
MCK = yf.download("MCK",start = "2022-01-01", end = "2022-12-31")["Adj Close"]

MCK_log_returns = np.log(MCK / MCK.shift(1))
print("Please see below for the statistic analysis for MCK:")
MCK_df = pd.DataFrame(MCK_log_returns)
MCK_stats = MCK_df.describe().rename(index={'mean':'Average','std':'Standard Deviation','25%':'25th Percentile','min':'Minimum','max':'Maximum','50%':'50th Percentile','75%':'75th Percentile'})
MCK_stats.drop(['count'], axis = 0, inplace = True )
MCK_stats
# Out:
# [*********************100%***********************]  1 of 1 completed
# Please see below for the statistic analysis for MCK:
#                     Adj Close
# Average              0.001678
# Standard Deviation   0.015140
# Minimum             -0.044525
# 25th Percentile     -0.007691
# 50th Percentile      0.002616
# 75th Percentile      0.011732
# Maximum              0.057808

# %%
tickers = ["CAH","MCK","MRK"]

#geting price from yahoo
MRK = yf.download("MRK",start = "2022-01-01", end = "2022-12-31")["Adj Close"]

MRK_log_returns = np.log(MRK / MRK.shift(1))
print("Please see below for the statistic analysis for MRK:")
MRK_df = pd.DataFrame(MRK_log_returns)
MRK_stats = MRK_df.describe().rename(index={'mean':'Average','std':'Standard Deviation','25%':'25th Percentile','min':'Minimum','max':'Maximum','50%':'50th Percentile','75%':'75th Percentile'})
MRK_stats.drop(['count'], axis = 0, inplace = True )
MRK_stats
# Out:
# [*********************100%***********************]  1 of 1 completed
# Please see below for the statistic analysis for MRK:
#                     Adj Close
# Average              0.001594
# Standard Deviation   0.012545
# Minimum             -0.039335
# 25th Percentile     -0.006494
# 50th Percentile      0.001507
# 75th Percentile      0.008698
# Maximum              0.048220

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# Define the tickers and the start and end dates
tickers = ["CAH", "MCK", "MRK", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
hc_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(hc_adj_close / hc_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plot.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax, color = 'purple')

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return of the 3 Top Performing Healthcare Stocks in Comparison with the S&P 500')

# Show the chart
plot.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# Analyzing the top 3 performing stocks in Consumer Staples

# %%
#Getting the statistics for the top performing stocks within the Consumer Staples' Sector
#top 3 performing stocks for Consumer Staples: LW, ADM, CPB

#geting price from yahoo
LW = yf.download("LW",start = "2022-01-01", end = "2022-12-31")["Adj Close"]

LW_log_returns = np.log(LW / LW.shift(1))
print("Please see below for the statistic analysis for LW:")
LW_df = pd.DataFrame(LW_log_returns)
LW_stats = LW_df.describe().rename(index={'mean':'Average','std':'Standard Deviation','25%':'25th Percentile','min':'Minimum','max':'Maximum','50%':'50th Percentile','75%':'75th Percentile'})
LW_stats.drop(['count'], axis = 0, inplace = True )
LW_stats
# Out:
# [*********************100%***********************]  1 of 1 completed
# Please see below for the statistic analysis for LW:
#                     Adj Close
# Average              0.001394
# Standard Deviation   0.018579
# Minimum             -0.097122
# 25th Percentile     -0.007971
# 50th Percentile      0.000541
# 75th Percentile      0.011805
# Maximum              0.076728

# %%
#Getting the statistics for the top performing stocks within the Consumer Staples' Sector
#top 3 performing stocks for Consumer Staples: LW, ADM, CPB

#geting price from yahoo
ADM = yf.download("ADM",start = "2022-01-01", end = "2022-12-31")["Adj Close"]

ADM_log_returns = np.log(ADM / ADM.shift(1))
print("Please see below for the statistic analysis for ADM:")
ADM_df = pd.DataFrame(ADM_log_returns)
ADM_stats = ADM_df.describe().rename(index={'mean':'Average','std':'Standard Deviation','25%':'25th Percentile','min':'Minimum','max':'Maximum','50%':'50th Percentile','75%':'75th Percentile'})
ADM_stats.drop(['count'], axis = 0, inplace = True )
ADM_stats
# Out:
# [*********************100%***********************]  1 of 1 completed
# Please see below for the statistic analysis for ADM:
#                     Adj Close
# Average              0.001328
# Standard Deviation   0.019771
# Minimum             -0.076187
# 25th Percentile     -0.007731
# 50th Percentile      0.002963
# 75th Percentile      0.013239
# Maximum              0.055475

# %%
#Getting the statistics for the top performing stocks within the Consumer Staples' Sector
#top 3 performing stocks for Consumer Staples: LW, ADM, CPB

#geting price from yahoo
CPB = yf.download("CPB",start = "2022-01-01", end = "2022-12-31")["Adj Close"]

CPB_log_returns = np.log(CPB / CPB.shift(1))
print("Please see below for the statistic analysis for CPB:")
CPB_df = pd.DataFrame(CPB_log_returns)
CPB_stats = CPB_df.describe().rename(index={'mean':'Average','std':'Standard Deviation','25%':'25th Percentile','min':'Minimum','max':'Maximum','50%':'50th Percentile','75%':'75th Percentile'})
CPB_stats.drop(['count'], axis = 0, inplace = True )
CPB_stats
# Out:
# [*********************100%***********************]  1 of 1 completed
# Please see below for the statistic analysis for CPB:
#                     Adj Close
# Average              0.001170
# Standard Deviation   0.015151
# Minimum             -0.084195
# 25th Percentile     -0.006240
# 50th Percentile      0.002072
# 75th Percentile      0.010133
# Maximum              0.058458

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# Define the tickers and the start and end dates
tickers = ["LW", "ADM", "CPB", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
cs_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(cs_adj_close / cs_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plot.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax, color = 'purple')

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title("Annualized Return of the 3 Top Performing Consumer Staples' Stocks in Comparison with the S&P 500")

# Show the chart
plot.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# Analysis of the Healthcare Sector Comparing with the S&P 500 (Annualized Comparsion)

# %%
import pandas as pd
import numpy as np
import yfinance as yf

#Getting the ticker symbols for everything within the healthcare sector
stock_df['Symbol']
healthcare = stock_df[stock_df["GICS Sector"] == "Health Care"]
healthcare_tickers = healthcare['Symbol'] 
healthcare_tickers = list(healthcare_tickers)
healthcare_tickers

# Download historical prices for each stock over the holding period
hc_adj_close = yf.download(healthcare_tickers, start='2022-01-01', end='2022-12-31')['Adj Close']

# Calculating the daily log returns for each stock
log_returns = np.log(hc_adj_close / hc_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Combine the daily returns of all stocks into a single DataFrame
annualized_returns['Healthcare'] = log_returns.mean(axis=1)

# Calculate the mean and standard deviation of the daily returns of the group
mean = annualized_returns['Healthcare'].mean()
std = annualized_returns['Healthcare'].std()
var = annualized_returns['Healthcare'].var()
max = annualized_returns['Healthcare'].max()
min = annualized_returns['Healthcare'].min()

print(f"Mean return of the Healthcare: {mean:.4f}")
print(f"Standard deviation of the Healthcare: {std:.4f}")
print(f"Variance of the Healthcare: {var:.4f}")
print(f"Max of the Healthcare: {max:.4f}")
print(f"Min of the Healthcare: {min:.4f}")
# Out:
# [*********************100%***********************]  65 of 65 completed
# Mean return of the Healthcare: -0.0005
# Standard deviation of the Healthcare: 0.0143
# Variance of the Healthcare: 0.0002
# Max of the Healthcare: 0.0425
# Min of the Healthcare: -0.0452

# %%
tickers = ["XLV", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
hc_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(hc_adj_close / hc_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plot.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax, color = 'purple')

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plot.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# Analysis of the Consumer Staples' Sector Comparing with the S&P 500 (Annualized Comparison)

# %%
import pandas as pd
import numpy as np
import yfinance as yf

#Getting the ticker symbols for everything within the healthcare sector
stock_df['Symbol']
Consumer_Staples = stock_df[stock_df["GICS Sector"] == "Consumer Staples"]
Consumer_Staples_tickers = Consumer_Staples['Symbol'] 
Consumer_Staples_tickers = list(Consumer_Staples_tickers)
Consumer_Staples_tickers[2] = 'BF-B'

# Download historical prices for each stock over the holding period
cs_adj_close = yf.download(Consumer_Staples_tickers, start='2022-01-01', end='2022-12-31')['Adj Close']

# Calculating the daily log returns for each stock
log_returns = np.log(cs_adj_close / cs_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Combine the daily returns of all stocks into a single DataFrame
annualized_returns['Consumer Staples'] = log_returns.mean(axis=1)

# Calculate the mean and standard deviation of the daily returns of the group
mean = annualized_returns['Consumer Staples'].mean()
std = annualized_returns['Consumer Staples'].std()
var = annualized_returns['Consumer Staples'].var()
max = annualized_returns['Consumer Staples'].max()
min = annualized_returns['Consumer Staples'].min()

print(f"Mean return of the Consumer Staples: {mean:.4f}")
print(f"Standard deviation of the Consumer Staples: {std:.4f}")
print(f"Variance of the Consumer Staples: {var:.4f}")
print(f"Max of the Consumer Staples: {max:.4f}")
print(f"Min of the Consumer Staples: {min:.4f}")
# Out:
# [*********************100%***********************]  37 of 37 completed
# Mean return of the Consumer Staples: 0.0000
# Standard deviation of the Consumer Staples: 0.0111
# Variance of the Consumer Staples: 0.0001
# Max of the Consumer Staples: 0.0329
# Min of the Consumer Staples: -0.0761

# %%
tickers = ["XLP", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
cs_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(cs_adj_close / cs_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plot.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax, color = 'purple')

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plot.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
# Import libraries
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Downloading and Extracting Tickers for Financials and Materials Sector in S&P 500

# %%
# Download the S&P 500 company data from Wikipedia in Data Frame
sp500_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_S%26P_500_companies")[0]

# %%
# Filter the DataFrame to only include companies in the Financials sector
financials_sp500_df = sp500_df[sp500_df["GICS Sector"] == "Financials"]

# Sort the filtered Data Frame by ticker symbol in alphabetical order
sorted_financials_sp500_df = financials_sp500_df.sort_values("Symbol")

# Extract the list of ticker symbols into list from the sorted Data Frame
financials_sp500_tickers = sorted_financials_sp500_df["Symbol"].tolist()

# Revised ticker name manually due to different name format
financials_sp500_tickers[13] = "BRK-B"

# Print the list of ticker symbols and number of stocks in Financials sector
print(financials_sp500_tickers)
len(financials_sp500_tickers)
# Out:
# ['ACGL', 'AFL', 'AIG', 'AIZ', 'AJG', 'ALL', 'AMP', 'AON', 'AXP', 'BAC', 'BEN', 'BK', 'BLK', 'BRK-B', 'BRO', 'C', 'CB', 'CBOE', 'CFG', 'CINF', 'CMA', 'CME', 'COF', 'DFS', 'FDS', 'FIS', 'FISV', 'FITB', 'FLT', 'FRC', 'GL', 'GPN', 'GS', 'HBAN', 'HIG', 'ICE', 'IVZ', 'JKHY', 'JPM', 'KEY', 'L', 'LNC', 'MA', 'MCO', 'MET', 'MKTX', 'MMC', 'MS', 'MSCI', 'MTB', 'NDAQ', 'NTRS', 'PFG', 'PGR', 'PNC', 'PRU', 'PYPL', 'RE', 'RF', 'RJF', 'SCHW', 'SPGI', 'STT', 'SYF', 'TFC', 'TROW', 'TRV', 'USB', 'V', 'WFC', 'WRB', 'WTW', 'ZION']
# 73

# %%
# Filter the DataFrame to only include companies in the Materials sector
materials_sp500_df = sp500_df[sp500_df["GICS Sector"] == "Materials"]

# Sort the filtered Data Frame by ticker symbol in alphabetical order
sorted_materials_sp500_df = materials_sp500_df.sort_values("Symbol")

# Extract the list of ticker symbols into list from the sorted Data Frame
materials_sp500_tickers = sorted_materials_sp500_df["Symbol"].tolist()

# Print the list of ticker symbols and number of stocks in Materials sector
print(materials_sp500_tickers)
len(materials_sp500_tickers)
# Out:
# ['ALB', 'AMCR', 'APD', 'AVY', 'BALL', 'CE', 'CF', 'CTVA', 'DD', 'DOW', 'ECL', 'EMN', 'FCX', 'FMC', 'IFF', 'IP', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PKG', 'PPG', 'SEE', 'SHW', 'STLD', 'VMC', 'WRK']
# 29

# %% [markdown]
# ## Downloading Stock Price Data and Calculating Daily Log-Returns, Visualization

# %%
# Download historical price data for each financials sector stocks
financials_adj_close = yf.download(financials_sp500_tickers,start = "2022-01-01", end = "2022-12-31")["Adj Close"]
print(financials_adj_close)
# Out:
# [*********************100%***********************]  73 of 73 completed
#                  ACGL        AFL        AIG         AIZ         AJG  \
# Date
# 2022-01-03  44.549999  56.456684  55.732071  152.707321  164.275589
# 2022-01-04  45.130001  58.307247  57.295559  154.143814  164.985092
# 2022-01-05  44.599998  58.210365  56.508953  152.746414  161.890945
# 2022-01-06  44.860001  59.285820  57.480072  152.277344  163.654800
# 2022-01-07  45.070000  60.225628  58.985291  155.121017  162.945312
# ...               ...        ...        ...         ...         ...
# 2022-12-23  63.380001  71.325623  62.738583  124.347359  187.858154
# 2022-12-27  63.619999  71.812721  62.907452  123.889877  188.725601
# 2022-12-28  62.599998  71.047279  62.470383  123.283203  187.399490
# 2022-12-29  63.110001  71.653671  63.205448  125.938622  189.612991
# 2022-12-30  62.779999  71.514503  62.818050  124.377197  187.987762
#
# ...

# %%
# Calculate the daily log-returns for each financials sector stocks
financials_log_returns = np.log(financials_adj_close/financials_adj_close.shift(1))
print(financials_log_returns)
# Out:
#                 ACGL       AFL       AIG       AIZ       AJG       ALL  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04  0.012935  0.032253  0.027667  0.009363  0.004310  0.023894
# 2022-01-05 -0.011813 -0.001663 -0.013824 -0.009107 -0.018932 -0.000909
# 2022-01-06  0.005813  0.018307  0.017039 -0.003076  0.010836  0.011339
# 2022-01-07  0.004670  0.015728  0.025850  0.018502 -0.004345  0.028591
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.008397  0.011776  0.012106  0.016613  0.002019  0.006917
# 2022-12-27  0.003779  0.006806  0.002688 -0.003686  0.004607 -0.002570
# 2022-12-28 -0.016163 -0.010716 -0.006972 -0.004909 -0.007051 -0.004347
# 2022-12-29  0.008114  0.008499  0.011698  0.021310  0.011742  0.007283
# 2022-12-30 -0.005243 -0.001944 -0.006148 -0.012476 -0.008608 -0.006029
#
#                  AMP       AON       AXP       BAC  ...       SYF       TFC  \
# ...

# %%
# Calculate annualized log-return
financials_annualized_returns = ((1 + financials_log_returns.mean()) ** 252 - 1) * 100

# Create Data Frame
financials_df = pd.DataFrame({"Annualized Returns" : financials_annualized_returns})

# Round the values to two decimal places
financials_df["Annualized Returns"] = financials_df["Annualized Returns"].round(2)

# Clone of financials_df
clone_financials_df = pd.DataFrame(financials_df)

#Sort Data
financials_df_sorted = clone_financials_df.sort_values(by="Annualized Returns", ascending=False)
print(financials_df_sorted)
# Out:
#       Annualized Returns
# ACGL               41.27
# WRB                36.09
# GL                 28.26
# PGR                27.85
# AFL                26.90
# ...                  ...
# FRC               -38.06
# FIS               -39.37
# TROW              -41.91
# LNC               -54.84
# PYPL              -63.83
#
# [73 rows x 1 columns]

# %%
# Visualize the annualized returns using a bar chart
financials_df_sorted.plot(kind='bar', figsize=(20,10))
plt.title('Performance of Financials Sector')
plt.ylabel('Annualized Returns (%)')
plt.show()

# %% [markdown]
# ### Materials Sector

# %%
# Download historical price data for each materials sector stocks
materials_adj_close = yf.download(materials_sp500_tickers,start = "2022-01-01", end = "2022-12-31")["Adj Close"]
print(materials_adj_close)
# Out:
# [*********************100%***********************]  29 of 29 completed
#                    ALB       AMCR         APD         AVY       BALL  \
# Date
# 2022-01-03  234.695984  11.291617  286.605286  206.572205  91.809311
# 2022-01-04  240.556686  11.472208  290.103027  211.579483  88.609871
# 2022-01-05  233.674561  11.491218  294.772949  209.678482  89.997932
# 2022-01-06  231.433411  11.396171  288.746552  209.707870  90.135757
# 2022-01-07  234.051407  11.519732  288.155518  208.953369  89.102081
# ...                ...        ...         ...         ...        ...
# 2022-12-23  226.536575  11.929075  308.474670  180.363144  51.445938
# 2022-12-27  213.760452  11.948857  308.632843  181.627899  51.605366
# 2022-12-28  213.640656  11.780704  306.102081  178.341507  50.399681
# 2022-12-29  217.064270  11.889509  307.851868  180.671860  51.435970
# 2022-12-30  216.455414  11.780704  306.331451  180.253586  50.957680
#
# ...

# %%
# Calculate the daily log-returns for each materials sector stocks
materials_log_returns = np.log(materials_adj_close/materials_adj_close.shift(1))
print(materials_log_returns)
# Out:
#                  ALB      AMCR       APD       AVY      BALL        CE  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04  0.024665  0.015867  0.012130  0.023951 -0.035470  0.027617
# 2022-01-05 -0.029026  0.001656  0.015969 -0.009025  0.015543  0.009480
# 2022-01-06 -0.009637 -0.008306 -0.020656  0.000140  0.001530 -0.012213
# 2022-01-07  0.011249  0.010784 -0.002049 -0.003604 -0.011534  0.002095
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.004327  0.006656 -0.001793  0.012781  0.009340  0.014041
# 2022-12-27 -0.058050  0.001657  0.000513  0.006988  0.003094  0.011536
# 2022-12-28 -0.000561 -0.014173 -0.008234 -0.018260 -0.023641 -0.031826
# 2022-12-29  0.015898  0.009194  0.005700  0.012982  0.020353  0.029317
# 2022-12-30 -0.002809 -0.009194 -0.004951 -0.002318 -0.009342 -0.012152
#
#                   CF      CTVA        DD       DOW  ...       MOS       NEM  \
# ...

# %%
# Calculate annualized log-return
materials_annualized_returns = ((1 + materials_log_returns.mean()) ** 252 - 1) * 100

# Create Data Frame
materials_df = pd.DataFrame({"Annualized Returns" : materials_annualized_returns})

# Round the values to two decimal places
materials_df["Annualized Returns"] = materials_df["Annualized Returns"].round(2)

# Clone of financials_df
clone_materials_df = pd.DataFrame(materials_df)

#Sort Data
materials_df_sorted = clone_materials_df.sort_values(by="Annualized Returns", ascending=False)
print(materials_df_sorted)
# Out:
#       Annualized Returns
# STLD               61.74
# CTVA               26.82
# CF                 22.81
# NUE                18.69
# FMC                15.55
# MOS                10.36
# APD                 6.94
# AMCR                4.37
# PKG                -1.52
# LYB                -1.98
# LIN                -2.21
# FCX                -6.84
# DOW                -6.95
# ALB                -7.83
# AVY               -12.84
# DD                -13.33
# VMC               -15.11
# WRK               -18.64
# NEM               -19.56
# MLM               -22.64
# IP                -22.90
# SEE               -24.21
# PPG               -25.09
# IFF               -27.82
# SHW               -29.56
# EMN               -29.85
# ECL               -36.05
# CE                -37.82
# BALL              -44.80

# %%
# Visualize the annualized returns using a bar chart
materials_df_sorted.plot(kind='bar', figsize=(20,10))
plt.title('Performance of Materials Sector')
plt.ylabel('Annualized Returns (%)')
plt.show()

# %% [markdown]
# ## Descriptive Statistics for Top 3 Stocks Daily Log Returns

# %%
financials_log_returns.reindex(columns=financials_df_sorted.head(3).index.tolist()).describe()
# Out:
#              ACGL         WRB          GL
# count  250.000000  250.000000  250.000000
# mean     0.001372    0.001224    0.000988
# std      0.017497    0.015742    0.015517
# min     -0.049759   -0.053204   -0.040014
# 25%     -0.008737   -0.009184   -0.008108
# 50%      0.001112    0.003106    0.002282
# 75%      0.012113    0.012395    0.011142
# max      0.092157    0.048287    0.045282

# %%
materials_log_returns.reindex(columns=materials_df_sorted.head(3).index.tolist()).describe()
# Out:
#              STLD        CTVA          CF
# count  250.000000  250.000000  250.000000
# mean     0.001910    0.000943    0.000816
# std      0.028554    0.017878    0.031260
# min     -0.094852   -0.069390   -0.094408
# 25%     -0.015842   -0.008088   -0.017167
# 50%      0.001689    0.000901    0.000928
# 75%      0.022201    0.010931    0.023121
# max      0.086998    0.050350    0.078042

# %% [markdown]
# ## Descriptivie Statistics for Each Sectors Annualized Returns

# %%
financials_df_sorted.describe()
# Out:
#        Annualized Returns
# count           73.000000
# mean            -9.480685
# std             20.681656
# min            -63.830000
# 25%            -22.030000
# 50%            -14.560000
# 75%              3.150000
# max             41.270000

# %%
materials_df_sorted.describe()
# Out:
#        Annualized Returns
# count           29.000000
# mean            -8.285172
# std             23.008743
# min            -44.800000
# 25%            -24.210000
# 50%            -12.840000
# 75%              4.370000
# max             61.740000

# %% [markdown]
# ## Comparision Between S&P500 and Top 3 Stocks

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Download S&P 500 Data
sp500_price = yf.download("^GSPC", start = "2022-01-01", end = "2022-12-31")

# Calculate the daily log-returns for S&P 500
sp500_returns = np.log(sp500_price / sp500_price.shift(1))

#Calculate annualized log-return
sp500_annualized_returns = ((1 + sp500_returns.mean()) ** 252 - 1)*100
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Financials Sector Top 3 - ACGL, WRB, GL

# %%
financials_top_stocks = financials_df_sorted.head(3)

plt.figure(figsize=(20,10))
plt.bar(financials_top_stocks.index, financials_top_stocks['Annualized Returns'], label='Top 3 Stocks')
plt.bar('S&P 500', sp500_annualized_returns, label='S&P 500')
plt.xticks(rotation=90, fontsize=12)
plt.yticks(range(-50, int(financials_top_stocks['Annualized Returns'].max())+5, 5))
plt.ylabel('Annualized returns (%)', fontsize=16)
plt.xlabel('Tickers', fontsize=14)
plt.title('Top Performing Financial Stocks VS S&P500', fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ### Materials Sector Top 3 - STLD, CTVA, CF

# %%
materials_top_stocks = materials_df_sorted.head(3)

plt.figure(figsize=(20,10))
plt.bar(materials_top_stocks.index, materials_top_stocks['Annualized Returns'], label='Top 3 Stocks')
plt.bar('S&P 500', sp500_annualized_returns, label='S&P 500')
plt.xticks(rotation=90, fontsize=12)
plt.yticks(range(-50, int(materials_top_stocks['Annualized Returns'].max())+5, 5))
plt.ylabel('Annualized returns (%)', fontsize=16)
plt.xlabel('Tickers', fontsize=14)
plt.title('Top Performing Material Stocks VS S&P500', fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## Comparision Between S&P500 and Each Sectors

# %% [markdown]
# ### Financial Sector

# %%
# Calculate the daily log-returns for financials sector ticker XLF
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

XLF_price = yf.download("XLF", start = "2022-01-01", end = "2022-12-31")
XLF_ajd_close = XLF_price["Adj Close"]

XLF_log_returns = np.log(XLF_ajd_close/XLF_ajd_close.shift(1))
print(XLF_log_returns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-01-03         NaN
# 2022-01-04    0.025969
# 2022-01-05   -0.011653
# 2022-01-06    0.014606
# 2022-01-07    0.011727
#                 ...
# 2022-12-23    0.005612
# 2022-12-27   -0.000295
# 2022-12-28   -0.003542
# 2022-12-29    0.013802
# 2022-12-30   -0.002628
# Name: Adj Close, Length: 251, dtype: float64

# %%
# Calculate annualized log-return
XLF_annualized_returns = ((1 + XLF_log_returns.mean()) ** 252 - 1) * 100
print(XLF_annualized_returns)
# Out:
# -11.76258890866977

# %%
plt.figure(figsize=(20,10))
plt.bar("XLF", XLF_annualized_returns, label="XLF")
plt.bar("S&P 500", sp500_annualized_returns, label="S&P 500")
plt.xticks(rotation=90, fontsize=12)
plt.ylabel("Annualized returns (%)", fontsize=16)
plt.xlabel("Tickers", fontsize=14)
plt.title("XLF VS S&P500", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ### Materials Sector

# %%
# Calculate the daily log-returns for financials sector ticker XLB
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

XLB_price = yf.download("XLB", start = "2022-01-01", end = "2022-12-31")
XLB_ajd_close = XLB_price["Adj Close"]

XLB_log_returns = np.log(XLB_ajd_close/XLB_ajd_close.shift(1))
print(XLB_log_returns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2022-01-03         NaN
# 2022-01-04    0.012225
# 2022-01-05   -0.000110
# 2022-01-06   -0.012674
# 2022-01-07   -0.000895
#                 ...
# 2022-12-23    0.006901
# 2022-12-27    0.000891
# 2022-12-28   -0.015387
# 2022-12-29    0.010796
# 2022-12-30   -0.007055
# Name: Adj Close, Length: 251, dtype: float64

# %%
# Calculate annualized log-return
XLB_annualized_returns = ((1 + XLB_log_returns.mean()) ** 252 - 1) * 100
print(XLB_annualized_returns)
# Out:
# -11.22613383092207

# %%
plt.figure(figsize=(20,10))
plt.bar("XLB", XLB_annualized_returns, label="XLB")
plt.bar("S&P 500", sp500_annualized_returns, label="S&P 500")
plt.xticks(rotation=90, fontsize=12)
plt.ylabel("Annualized returns (%)", fontsize=16)
plt.xlabel("Tickers", fontsize=14)
plt.title("XLB VS S&P500", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# pip install yfinance

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Downloaded the Ticker Symbols from Wikipedia and counted tickers of Industrials Sector

# %%
import pandas as pd
import yfinance as yf

# Define the S&P 500 ticker symbol
SP500_TICKER = 'GSPC'

# Download the S&P 500 company data from Wikipedia
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Filter the DataFrame to only include companies in the Industrials sector
industrials_sp500_df = sp500_df[sp500_df['GICS Sector'] == 'Industrials']

# Sort the filtered DataFrame by ticker symbol in alphabetical order
sorted_industrials_sp500_df = industrials_sp500_df.sort_values('Symbol')

# Extract the list of ticker symbols from the sorted DataFrame
industrials_sp500_tickers = sorted_industrials_sp500_df['Symbol'].tolist()

# Print the list of ticker symbols
print(industrials_sp500_tickers)
len(industrials_sp500_tickers)
# Out:
# ['AAL', 'ADP', 'ALK', 'ALLE', 'AME', 'AOS', 'BA', 'BR', 'CARR', 'CAT', 'CHRW', 'CMI', 'CPRT', 'CSGP', 'CSX', 'CTAS', 'DAL', 'DE', 'DOV', 'EFX', 'EMR', 'ETN', 'EXPD', 'FAST', 'FDX', 'FTV', 'GD', 'GE', 'GNRC', 'GWW', 'HII', 'HON', 'HWM', 'IEX', 'IR', 'ITW', 'J', 'JBHT', 'JCI', 'LDOS', 'LHX', 'LMT', 'LUV', 'MAS', 'MMM', 'NDSN', 'NOC', 'NSC', 'ODFL', 'OTIS', 'PAYX', 'PCAR', 'PH', 'PNR', 'PWR', 'RHI', 'ROK', 'ROL', 'RSG', 'RTX', 'SNA', 'SWK', 'TDG', 'TT', 'TXT', 'UAL', 'UNP', 'UPS', 'URI', 'VRSK', 'WAB', 'WM', 'XYL']
# 73

# %% [markdown]
# # Downloaded the Ticker Symbols from Wikipedia and counted for tickers of Communication Services Sector

# %%
import pandas as pd
import yfinance as yf

# Define the S&P 500 ticker symbol
SP500_TICKER = 'GSPC'

# Retrieve the list of Energy sector companies from Yahoo Finance
#energy_sp500_df = yf.download(sp500_df[sp500_df['GICS Sector'] == 'Energy']['TICKER'].tolist())

# Download the S&P 500 company data from Wikipedia
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Filter the DataFrame to only include companies in the Energy sector
communicationservices_sp500_df = sp500_df[sp500_df['GICS Sector'] == 'Communication Services']

# Sort the filtered DataFrame by ticker symbol in alphabetical order
sorted_communicationservices_sp500_df = communicationservices_sp500_df.sort_values('Symbol')

# Extract the list of ticker symbols from the sorted DataFrame
communicationservices_sp500_tickers = sorted_communicationservices_sp500_df['Symbol'].tolist()

# Print the list of ticker symbols
print(communicationservices_sp500_tickers)
len(communicationservices_sp500_tickers)
# Out:
# ['ATVI', 'CHTR', 'CMCSA', 'DIS', 'DISH', 'EA', 'FOX', 'FOXA', 'GOOG', 'GOOGL', 'IPG', 'LYV', 'META', 'MTCH', 'NFLX', 'NWS', 'NWSA', 'OMC', 'PARA', 'T', 'TMUS', 'TTWO', 'VZ', 'WBD']
# 24

# %% [markdown]
# # Testing how to download the data from Yahoo Finance

# %%
import yfinance as yf
df_AAL = yf.download("AAL", start = "2022-01-01", end = "2022-12-31", group_by = "ticker")
df_AAL
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-01-03  18.230000  19.180000  18.200001  18.750000  18.750000  42781000
# 2022-01-04  19.219999  19.459999  18.850000  19.020000  19.020000  29266600
# 2022-01-05  19.129999  19.389999  18.510000  18.680000  18.680000  34447900
# 2022-01-06  18.889999  19.059999  18.350000  18.570000  18.570000  19097700
# 2022-01-07  18.750000  19.590000  18.580000  19.280001  19.280001  42399500
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  12.510000  12.710000  12.330000  12.710000  12.710000  17181200
# 2022-12-27  12.620000  12.790000  12.400000  12.530000  12.530000  18878200
# 2022-12-28  12.520000  12.680000  12.250000  12.320000  12.320000  20470400
# 2022-12-29  12.390000  12.710000  12.300000  12.700000  12.700000  19706300
# ...

# %%
import yfinance as yf
df_ADP = yf.download("ADP", start = "2022-01-01", end = "2022-12-31", group_by = "ticker")
df_ADP
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  245.059998  247.470001  241.429993  244.009995  238.103592
# 2022-01-04  243.179993  247.039993  243.179993  245.149994  239.215973
# 2022-01-05  244.580002  246.490005  242.830002  243.059998  237.176605
# 2022-01-06  242.460007  244.690002  240.630005  241.389999  235.546997
# 2022-01-07  240.779999  241.240005  238.729996  238.839996  233.058731
# ...                ...         ...         ...         ...         ...
# 2022-12-23  237.919998  241.649994  236.589996  240.940002  239.583176
# 2022-12-27  241.369995  242.190002  239.339996  241.029999  239.672668
# 2022-12-28  241.350006  242.740005  237.720001  237.850006  236.510574
# 2022-12-29  238.179993  241.830002  238.179993  240.619995  239.264969
# 2022-12-30  239.699997  240.199997  236.050003  238.860001  237.514893
#
#              Volume
# Date
# ...

# %%
import yfinance as yf
df_ALK = yf.download("ALK", start = "2022-01-01", end = "2022-12-31", group_by = "ticker")
df_ALK
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-01-03  52.860001  54.630001  52.830002  54.070000  54.070000  1942000
# 2022-01-04  55.189999  55.610001  54.330002  55.450001  55.450001  2613800
# 2022-01-05  55.820000  56.330002  54.709999  54.770000  54.770000  1914900
# 2022-01-06  55.689999  55.990002  54.169998  54.459999  54.459999  1593400
# 2022-01-07  55.070000  56.680000  54.730000  55.860001  55.860001  1831800
# ...               ...        ...        ...        ...        ...      ...
# 2022-12-23  42.860001  43.459999  42.610001  43.310001  43.310001   970300
# 2022-12-27  42.869999  43.020000  41.880001  42.259998  42.259998  1878300
# 2022-12-28  42.040001  42.580002  41.290001  41.299999  41.299999  1681800
# 2022-12-29  41.490002  42.820000  41.410000  42.810001  42.810001  1374500
# ...

# %%
import yfinance as yf
df_ALLE = yf.download("ALLE", start = "2022-01-01", end = "2022-12-31", group_by = "ticker")
df_ALLE
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2022-01-03  132.179993  132.300003  127.779999  129.360001  127.268600  608900
# 2022-01-04  130.360001  132.839996  130.309998  132.399994  130.259460  457000
# 2022-01-05  132.740005  133.520004  129.220001  129.309998  127.219429  624600
# 2022-01-06  129.339996  129.729996  127.839996  128.070007  125.999474  476800
# 2022-01-07  127.730003  128.809998  126.419998  126.629997  124.582756  838200
# ...                ...         ...         ...         ...         ...     ...
# 2022-12-23  104.889999  105.580002  104.279999  105.029999  104.584038  390500
# 2022-12-27  104.930000  106.089996  104.239998  105.980003  105.530006  443000
# 2022-12-28  106.349998  106.800003  104.129997  104.320000  103.877052  269200
# 2022-12-29  105.089996  106.830002  104.419998  106.739998  106.286774  302700
# ...

# %%
import yfinance as yf
df_AME = yf.download("AME", start = "2022-01-01", end = "2022-12-31", group_by = "ticker")
df_AME
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  147.250000  147.399994  142.759995  143.669998  142.442444
# 2022-01-04  144.500000  146.520004  143.929993  146.089996  144.841751
# 2022-01-05  146.580002  147.520004  143.289993  143.429993  142.204483
# 2022-01-06  143.759995  146.020004  143.210007  145.149994  143.909805
# 2022-01-07  145.100006  145.820007  142.320007  142.380005  141.163467
# ...                ...         ...         ...         ...         ...
# 2022-12-23  138.029999  139.419998  137.770004  139.380005  139.132477
# 2022-12-27  139.889999  140.669998  139.220001  140.130005  139.881149
# 2022-12-28  140.619995  141.479996  138.320007  138.360001  138.114288
# 2022-12-29  139.160004  140.949997  139.020004  140.369995  140.120712
# 2022-12-30  140.000000  140.190002  138.350006  139.720001  139.471863
#
#              Volume
# Date
# ...

# %% [markdown]
# # Calculated the Annualized Returns and sorted each stock of Industrials Sector from top to the worst performance

# %%
# import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ['AAL', 'ADP', 'ALK', 'ALLE', 'AME', 'AOS', 'BA', 'BR', 'CARR', 'CAT', 'CHRW', 'CMI', 'CPRT', 'CSGP', 'CSX', 'CTAS', 'DAL', 'DE', 'DOV', 'EFX', 'EMR', 'ETN', 'EXPD', 'FAST', 'FDX', 'FTV', 'GD', 'GE', 'GNRC', 'GWW', 'HII', 'HON', 'HWM', 'IEX', 'IR', 'ITW', 'J', 'JBHT', 'JCI', 'LDOS', 'LHX', 'LMT', 'LUV', 'MAS', 'MMM', 'NDSN', 'NOC', 'NSC', 'ODFL', 'OTIS', 'PAYX', 'PCAR', 'PH', 'PNR', 'PWR', 'RHI', 'ROK', 'ROL', 'RSG', 'RTX', 'SNA', 'SWK', 'TDG', 'TT', 'TXT', 'UAL', 'UNP', 'UPS', 'URI', 'VRSK', 'WAB', 'WM', 'XYL']
# Define the start and end dates
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
industrials_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(industrials_adj_close / industrials_adj_close.shift(1))
print(log_returns)
# Out:
# [*********************100%***********************]  73 of 73 completed
#                  AAL       ADP       ALK      ALLE       AME       AOS  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04  0.014297  0.004661  0.025202  0.023228  0.016704  0.016496
# 2022-01-05 -0.018038 -0.008562 -0.012339 -0.023615 -0.018376 -0.016855
# 2022-01-06 -0.005906 -0.006894 -0.005676 -0.009636  0.011920  0.006681
# 2022-01-07  0.037521 -0.010620  0.025382 -0.011308 -0.019268 -0.011360
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.011872  0.007415  0.009978 -0.001427  0.007634  0.011845
# 2022-12-27 -0.014263  0.000373 -0.024543  0.009004  0.005367  0.013442
# 2022-12-28 -0.016902 -0.013281 -0.022978 -0.015787 -0.012712 -0.015729
# 2022-12-29  0.030378  0.011579  0.035909  0.022933  0.014423  0.015556
# 2022-12-30  0.001574 -0.007341  0.003032 -0.013962 -0.004641 -0.007311
#
# ...

# %%
#Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

#Creating a df
industrials_df = pd.DataFrame({'Annualized Returns': annualized_returns})
industrials_df["Annualized Returns"] = industrials_df["Annualized Returns"].round(2)
industrials_df_sorted = industrials_df.sort_values(by = "Annualized Returns", ascending = False)
print(industrials_df_sorted)

# Visualize the holding period returns using a bar chart
industrials_df_sorted.plot(kind='bar', figsize=(10,10))
plt.title('Annualized Returns for Industrials Stocks')
plt.ylabel('Return (%)')
plt.show()
# Out:
#       Annualized Returns
# NOC                43.97
# LMT                41.25
# PWR                27.44
# HII                27.03
# DE                 24.18
# ...                  ...
# FDX               -31.84
# AAL               -32.39
# PNR               -35.83
# SWK               -58.68
# GNRC              -71.44
#
# [73 rows x 1 columns]

# %% [markdown]
# # Calculated the Annualized Returns and sorted each stock of  Communication Services Sector form top to worst performance

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ['ATVI', 'CHTR', 'CMCSA', 'DIS', 'DISH', 'EA', 'FOX', 'FOXA', 'GOOG', 'GOOGL', 'IPG', 'LYV', 'META', 'MTCH', 'NFLX', 'NWS', 'NWSA', 'OMC', 'PARA', 'T', 'TMUS', 'TTWO', 'VZ', 'WBD']
# Define the start and end dates
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
communication_services_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(communication_services_adj_close / communication_services_adj_close.shift(1))
print(log_returns)
# Out:
# [*********************100%***********************]  24 of 24 completed
#                 ATVI      CHTR     CMCSA       DIS      DISH        EA  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.003268 -0.010572 -0.005960 -0.006592  0.014020  0.005984
# 2022-01-05 -0.013634 -0.025143  0.000598 -0.003474 -0.022163 -0.014543
# 2022-01-06 -0.037972  0.011283  0.005758  0.010958 -0.001819 -0.031199
# 2022-01-07  0.003441 -0.034548 -0.009149  0.005910  0.042180  0.015987
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.003297  0.030528  0.009148  0.015343  0.022379  0.000741
# 2022-12-27 -0.002109 -0.003390 -0.003992 -0.018810 -0.018144 -0.005695
# 2022-12-28  0.003425 -0.001353 -0.010917 -0.025802 -0.050552 -0.010651
# 2022-12-29  0.009293  0.019665  0.012344  0.035136  0.044903  0.021926
# 2022-12-30 -0.002740  0.000472 -0.002285 -0.003447 -0.005682 -0.000082
#
# ...

# %%
#Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

#Creating a df
communication_services_df = pd.DataFrame({'Annualized Returns': annualized_returns})
communication_services_df["Annualized Returns"] = communication_services_df["Annualized Returns"].round(2)
communication_services_df_sorted = communication_services_df.sort_values(by = "Annualized Returns", ascending = False)
communication_services_df_sorted
print(communication_services_df_sorted)

# Visualize the holding period returns using a bar chart
communication_services_df_sorted.plot(kind='bar', figsize=(10,10))
plt.title('Annualized Returns for Communication Services Stocks')
plt.ylabel('Return (%)')
plt.show()
# Out:
#        Annualized Returns
# TMUS                22.53
# OMC                 14.87
# ATVI                14.33
# T                    3.02
# IPG                 -8.38
# EA                  -9.02
# FOX                -17.66
# FOXA               -18.39
# NWS                -18.72
# NWSA               -19.38
# VZ                 -20.91
# CMCSA              -29.47
# GOOG               -39.11
# GOOGL              -39.42
# TTWO               -41.99
# LYV                -42.72
# DIS                -44.88
# PARA               -45.83
# CHTR               -47.95
# NFLX               -50.96
# DISH               -58.18
# WBD                -62.94
# META               -64.82
# MTCH               -69.46

# %% [markdown]
# # 3 Best Performing Stocks of Industrial Sector - Statistical Analysis & Comparison with S&P 500

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ["NOC","LMT","PWR"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Download historical price data for each stock
prices = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Create a new dataframe to hold the holding period returns
df = pd.DataFrame()

# Calculating the daily log returns for each stock and add it to the dataframe
for ticker in tickers:
    df[ticker + '_Log_Returns'] = np.log(prices[ticker]/prices[ticker].shift(1))

mean = df[['NOC_Log_Returns', 'LMT_Log_Returns', 'PWR_Log_Returns']].mean()
std = df[['NOC_Log_Returns', 'LMT_Log_Returns', 'PWR_Log_Returns']].std()
var = df[['NOC_Log_Returns', 'LMT_Log_Returns', 'PWR_Log_Returns']].var()
max = df[['NOC_Log_Returns', 'LMT_Log_Returns', 'PWR_Log_Returns']].max()
min = df[['NOC_Log_Returns', 'LMT_Log_Returns', 'PWR_Log_Returns']].min()

print("Mean:")
print(mean)

print("Standard deviation:")
print(std)

print("Variance:")
print(var)

print("Maximum:")
print(max)

print("Minimum:")
print(min)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Mean:
# NOC_Log_Returns    0.001447
# LMT_Log_Returns    0.001371
# PWR_Log_Returns    0.000963
# dtype: float64
# Standard deviation:
# NOC_Log_Returns    0.019849
# LMT_Log_Returns    0.016617
# PWR_Log_Returns    0.024572
# dtype: float64
# Variance:
# NOC_Log_Returns    0.000394
# LMT_Log_Returns    0.000276
# PWR_Log_Returns    0.000604
# dtype: float64
# Maximum:
# NOC_Log_Returns    0.076275
# LMT_Log_Returns    0.083338
# PWR_Log_Returns    0.100732
# dtype: float64
# Minimum:
# NOC_Log_Returns   -0.077190
# LMT_Log_Returns   -0.062847
# PWR_Log_Returns   -0.095622
# dtype: float64

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["NOC","LMT","PWR","^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
industrials_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(industrials_adj_close / industrials_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# # 3 Best Performing Stocks of Communication Services - Statistical Analysis & Comparison with S&P 500

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ['TMUS','ATVI','OMC']
start_date = '2022-01-01'
end_date = '2022-12-31'

# Download historical price data for each stock
prices = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Create a new dataframe to hold the holding period returns
df = pd.DataFrame()

# Calculating the daily log returns for each stock and add it to the dataframe
for ticker in tickers:
    df[ticker + '_Log_Returns'] = np.log(prices[ticker]/prices[ticker].shift(1))

mean = df[['TMUS_Log_Returns', 'ATVI_Log_Returns', 'OMC_Log_Returns']].mean()
std = df[['TMUS_Log_Returns', 'ATVI_Log_Returns', 'OMC_Log_Returns']].std()
var = df[['TMUS_Log_Returns', 'ATVI_Log_Returns', 'OMC_Log_Returns']].var()
max = df[['TMUS_Log_Returns', 'ATVI_Log_Returns', 'OMC_Log_Returns']].max()
min = df[['TMUS_Log_Returns', 'ATVI_Log_Returns', 'OMC_Log_Returns']].min()

print("Mean:")
print(mean)

print("Standard deviation:")
print(std)

print("Variance:")
print(var)

print("Maximum:")
print(max)

print("Minimum:")
print(min)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Mean:
# TMUS_Log_Returns    0.000807
# ATVI_Log_Returns    0.000532
# OMC_Log_Returns     0.000550
# dtype: float64
# Standard deviation:
# TMUS_Log_Returns    0.018478
# ATVI_Log_Returns    0.017400
# OMC_Log_Returns     0.020694
# dtype: float64
# Variance:
# TMUS_Log_Returns    0.000341
# ATVI_Log_Returns    0.000303
# OMC_Log_Returns     0.000428
# dtype: float64
# Maximum:
# TMUS_Log_Returns    0.097316
# ATVI_Log_Returns    0.230123
# OMC_Log_Returns     0.132707
# dtype: float64
# Minimum:
# TMUS_Log_Returns   -0.071675
# ATVI_Log_Returns   -0.041589
# OMC_Log_Returns    -0.087994
# dtype: float64

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["TMUS","ATVI","OMC","^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
communication_services_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(communication_services_adj_close / communication_services_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# # Statistical Analysis of Industrial and Communication Services Sector

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the list of 73 stocks
stock_list = ['AAL', 'ADP', 'ALK', 'ALLE', 'AME', 'AOS', 'BA', 'BR', 'CARR', 'CAT', 'CHRW', 'CMI', 'CPRT', 'CSGP', 'CSX', 'CTAS', 'DAL', 'DE', 'DOV', 'EFX', 'EMR', 'ETN', 'EXPD', 'FAST', 'FDX', 'FTV', 'GD', 'GE', 'GNRC', 'GWW', 'HII', 'HON', 'HWM', 'IEX', 'IR', 'ITW', 'J', 'JBHT', 'JCI', 'LDOS', 'LHX', 'LMT', 'LUV', 'MAS', 'MMM', 'NDSN', 'NOC', 'NSC', 'ODFL', 'OTIS', 'PAYX', 'PCAR', 'PH', 'PNR', 'PWR', 'RHI', 'ROK', 'ROL', 'RSG', 'RTX', 'SNA', 'SWK', 'TDG', 'TT', 'TXT', 'UAL', 'UNP', 'UPS', 'URI', 'VRSK', 'WAB', 'WM', 'XYL']

# Download historical prices for each stock over the holding period
prices = yf.download(stock_list, start='2022-01-01', end='2022-12-31')['Adj Close']

# Calculating the daily log returns for each stock
log_returns = np.log(industrials_adj_close / industrials_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Combine the daily returns of all stocks into a single DataFrame
annualized_returns['Industrials'] = log_returns.mean(axis=1)

# Calculate the mean and standard deviation of the daily returns of the group
mean = annualized_returns['Industrials'].mean()
std = annualized_returns['Industrials'].std()
var = annualized_returns['Industrials'].var()
max = annualized_returns['Industrials'].max()
min = annualized_returns['Industrials'].min()

print(f"Mean return of the Industrials: {mean:.4f}")
print(f"Standard deviation of the Industrials: {std:.4f}")
print(f"Variance of the Industrials: {var:.4f}")
print(f"Max of the Industrials: {max:.4f}")
print(f"Min of the Industrials: {min:.4f}")
# Out:
# [*********************100%***********************]  73 of 73 completed
# Mean return of the Industrials: 0.0007
# Standard deviation of the Industrials: 0.0144
# Variance of the Industrials: 0.0002
# Max of the Industrials: 0.0469
# Min of the Industrials: -0.0491

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the list of 24 stocks
stock_list = ['ATVI', 'CHTR', 'CMCSA', 'DIS', 'DISH', 'EA', 'FOX', 'FOXA', 'GOOG', 'GOOGL', 'IPG', 'LYV', 'META', 'MTCH', 'NFLX', 'NWS', 'NWSA', 'OMC', 'PARA', 'T', 'TMUS', 'TTWO', 'VZ', 'WBD']

# Download historical prices for each stock over the holding period
prices = yf.download(stock_list, start='2022-01-01', end='2022-12-31')['Adj Close']

# Calculating the daily log returns for each stock
log_returns = np.log(communication_services_adj_close / communication_services_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100


# Combine the daily returns of all stocks into a single DataFrame
annualized_returns['CommunicationServices'] = log_returns.mean(axis=1)

# Calculate the mean and standard deviation of the daily returns of the group
mean = annualized_returns['CommunicationServices'].mean()
std = annualized_returns['CommunicationServices'].std()
var = annualized_returns['CommunicationServices'].var()
max = annualized_returns['CommunicationServices'].max()
min = annualized_returns['CommunicationServices'].min()

print(f"Mean return of the CommunicationServices: {mean:.4f}")
print(f"Standard deviation of the CommunicationServices: {std:.4f}")
print(f"Variance of the CommunicationServices: {var:.4f}")
print(f"Max of the CommunicationServices: {max:.4f}")
print(f"Min of the CommunicationServices: {min:.4f}")
# Out:
# [*********************100%***********************]  24 of 24 completed
# Mean return of the CommunicationServices: 0.0002
# Standard deviation of the CommunicationServices: 0.0128
# Variance of the CommunicationServices: 0.0002
# Max of the CommunicationServices: 0.0469
# Min of the CommunicationServices: -0.0390

# %% [markdown]
# # Comparison of Industrial & Communication Services Sector with S&P 500

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ['XLC', 'XLI','^GSPC']
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
industrials_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(industrials_adj_close / industrials_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)


# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)
print(sorted_returns)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  3 of 3 completed
# XLI     -0.048237
# ^GSPC   -0.201034
# XLC     -0.383256
# dtype: float64

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Testing data downloads from yfinance

# %%
import yfinance as yf
data = yf.download("AAPL", start = "2022-01-01", end = "2022-12-31", group_by = "ticker")
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  180.683868
# 2022-01-04  182.630005  182.940002  179.119995  179.699997  178.390701
# 2022-01-05  179.610001  180.169998  174.639999  174.919998  173.645523
# 2022-01-06  172.699997  175.300003  171.639999  172.000000  170.746811
# 2022-01-07  172.889999  174.139999  171.029999  172.169998  170.915573
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.658981
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.831772
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.847855
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.412415
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.731918
#
#                Volume
# Date
# ...

# %% [markdown]
# # Extracted the energy sector ticker symbols in alphabetical order + counted tickers

# %%
import pandas as pd
import yfinance as yf

# %%
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')

# %%
import pandas as pd
import yfinance as yf

# Define the S&P 500 ticker symbol
SP500_TICKER = 'GSPC'

# Retrieve the list of Energy sector companies from Yahoo Finance
#energy_sp500_df = yf.download(sp500_df[sp500_df['GICS Sector'] == 'Energy']['TICKER'].tolist())

# Download the S&P 500 company data from Wikipedia
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Filter the DataFrame to only include companies in the Energy sector
energy_sp500_df = sp500_df[sp500_df['GICS Sector'] == 'Energy']

# Sort the filtered DataFrame by ticker symbol in alphabetical order
sorted_energy_sp500_df = energy_sp500_df.sort_values('Symbol')

# Extract the list of ticker symbols from the sorted DataFrame
energy_sp500_tickers = sorted_energy_sp500_df['Symbol'].tolist()

# Print the list of ticker symbols
print(energy_sp500_tickers)
len(energy_sp500_tickers)
# Out:
# ['APA', 'BKR', 'COP', 'CTRA', 'CVX', 'DVN', 'EOG', 'EQT', 'FANG', 'HAL', 'HES', 'KMI', 'MPC', 'MRO', 'OKE', 'OXY', 'PSX', 'PXD', 'SLB', 'TRGP', 'VLO', 'WMB', 'XOM']
# 23

# %% [markdown]
# # Extracted the real estate ticker symbols in alphabetical order + counted tickers

# %%
import pandas as pd
import yfinance as yf

# Define the S&P 500 ticker symbol
SP500_TICKER = 'GSPC'

# Retrieve the list of Energy sector companies from Yahoo Finance
#energy_sp500_df = yf.download(sp500_df[sp500_df['GICS Sector'] == 'Energy']['TICKER'].tolist())

# Download the S&P 500 company data from Wikipedia
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Filter the DataFrame to only include companies in the Energy sector
realestate_sp500_df = sp500_df[sp500_df['GICS Sector'] == 'Real Estate']

# Sort the filtered DataFrame by ticker symbol in alphabetical order
sorted_realestate_sp500_df = realestate_sp500_df.sort_values('Symbol')

# Extract the list of ticker symbols from the sorted DataFrame
realestate_sp500_tickers = sorted_realestate_sp500_df['Symbol'].tolist()

# Print the list of ticker symbols
print(realestate_sp500_tickers)
len(realestate_sp500_tickers)
# Out:
# ['AMT', 'ARE', 'AVB', 'BXP', 'CBRE', 'CCI', 'CPT', 'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'HST', 'INVH', 'IRM', 'KIM', 'MAA', 'O', 'PEAK', 'PLD', 'PSA', 'REG', 'SBAC', 'SPG', 'UDR', 'VICI', 'VTR', 'WELL', 'WY']
# 30

# %% [markdown]
# # Extracted the consumer discretionary sector ticker symbols in alphabetical order + counted tickers

# %%
import pandas as pd
import yfinance as yf

# Define the S&P 500 ticker symbol
SP500_TICKER = 'GSPC'

# Retrieve the list of Energy sector companies from Yahoo Finance
#energy_sp500_df = yf.download(sp500_df[sp500_df['GICS Sector'] == 'Energy']['TICKER'].tolist())

# Download the S&P 500 company data from Wikipedia
sp500_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]

# Filter the DataFrame to only include companies in the Energy sector
consumerdiscretionary_sp500_df = sp500_df[sp500_df['GICS Sector'] == 'Consumer Discretionary']

# Sort the filtered DataFrame by ticker symbol in alphabetical order
sorted_consumerdiscretionary_sp500_df = consumerdiscretionary_sp500_df.sort_values('Symbol')

# Extract the list of ticker symbols from the sorted DataFrame
consumerdiscretionary_sp500_tickers = sorted_consumerdiscretionary_sp500_df['Symbol'].tolist()

# Print the list of ticker symbols
print(consumerdiscretionary_sp500_tickers)
len(consumerdiscretionary_sp500_tickers)
# Out:
# ['AAP', 'AMZN', 'APTV', 'AZO', 'BBWI', 'BBY', 'BKNG', 'BWA', 'CCL', 'CMG', 'CZR', 'DHI', 'DPZ', 'DRI', 'EBAY', 'ETSY', 'EXPE', 'F', 'GM', 'GPC', 'GRMN', 'HAS', 'HD', 'HLT', 'KMX', 'LEN', 'LKQ', 'LOW', 'LVS', 'MAR', 'MCD', 'MGM', 'MHK', 'NCLH', 'NKE', 'NVR', 'NWL', 'ORLY', 'PHM', 'POOL', 'RCL', 'RL', 'ROST', 'SBUX', 'TJX', 'TPR', 'TSCO', 'TSLA', 'ULTA', 'VFC', 'WHR', 'WYNN', 'YUM']
# 53

# %% [markdown]
# # Annualized Returns for Energy stocks in descending order

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ['APA', 'BKR', 'COP', 'CTRA', 'CVX', 'DVN', 'EOG', 'EQT', 'FANG', 'HAL', 'HES', 'KMI', 'MPC', 'MRO', 'OKE', 'OXY', 'PSX', 'PXD', 'SLB', 'TRGP', 'VLO', 'WMB', 'XOM']
# Define the start and end dates
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
energy_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(energy_adj_close / energy_adj_close.shift(1))
print(log_returns*100)
# Out:
# [*********************100%***********************]  23 of 23 completed
#                  APA       BKR       COP      CTRA       CVX       DVN  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04  4.868842  2.172716  4.246385  6.718577  1.803197  4.484299
# 2022-01-05 -3.664423  0.351081 -1.729846 -1.201651  0.648475 -2.227751
# 2022-01-06  4.206063  1.045907  3.685390 -1.069529  0.847322  3.706470
# 2022-01-07  0.168664  0.652977  2.702346  5.190403  1.425771  1.069312
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  5.570294  2.575849  4.231820  2.776286  3.044755  3.915024
# 2022-12-27  0.822010  0.923558  1.205852  1.496673  1.249223  1.161056
# 2022-12-28 -5.301822 -2.831688 -2.703557 -4.845789 -1.486257 -3.786808
# 2022-12-29  1.602834  2.182666  0.932248  0.613623  0.754307  0.246040
# 2022-12-30  1.663295  1.192315  1.373804  0.203707  0.653979  0.767033
#
# ...

# %%
#Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

#Creating a df
energy_df = pd.DataFrame({'Annualized Returns': annualized_returns})
energy_df["Annualized Returns"] = energy_df["Annualized Returns"].round(2)
energy_df_sorted = energy_df.sort_values(by = "Annualized Returns", ascending = False)
print(energy_df_sorted)

# Visualize the holding period returns using a bar chart
energy_df_sorted.plot(kind='bar', figsize=(10,10))
plt.title('Annualized Returns for Energy Stocks')
plt.ylabel('Return (%)')
plt.show()
# Out:
#       Annualized Returns
# OXY               105.46
# HES                87.84
# MPC                82.62
# XOM                81.21
# SLB                71.68
# VLO                70.98
# APA                69.70
# COP                68.60
# HAL                66.90
# MRO                63.01
# EQT                58.08
# CVX                56.42
# EOG                53.34
# DVN                46.23
# PSX                43.48
# TRGP               41.36
# CTRA               37.63
# PXD                35.68
# WMB                30.79
# FANG               30.77
# BKR                21.21
# KMI                17.75
# OKE                16.56

# %% [markdown]
# # Annualized Returns for the Real Estate stocks in descending order

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ['AMT', 'ARE', 'AVB', 'BXP', 'CBRE', 'CCI', 'CPT', 'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'HST', 'INVH', 'IRM', 'KIM', 'MAA', 'O', 'PEAK', 'PLD', 'PSA', 'REG', 'SBAC', 'SPG', 'UDR', 'VICI', 'VTR', 'WELL', 'WY']
# Define the start and end dates
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
realestate_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(realestate_adj_close / realestate_adj_close.shift(1))
print(log_returns*100)
# Out:
# [*********************100%***********************]  30 of 30 completed
#                  AMT       ARE       AVB       BXP      CBRE       CCI  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -1.268586  0.449344  0.984763  3.272519  1.488820 -2.727727
# 2022-01-05 -6.652797 -6.632150 -1.568369 -1.356696 -3.299536 -7.012425
# 2022-01-06  0.120888  1.531889  0.310083  2.056251 -0.950911  2.121033
# 2022-01-07  0.635948 -0.401108 -1.222053  0.662861 -0.883658  1.151802
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.874595  0.797799  0.726413  0.219537  1.299654  1.012547
# 2022-12-27  0.004738 -0.537996 -0.141172  0.728331 -0.235049 -0.036514
# 2022-12-28 -0.380036 -2.069750 -1.062133 -3.786314 -1.422004 -1.523257
# 2022-12-29  2.649032  2.059636  1.961942  3.280963  2.798299  2.598315
# 2022-12-30 -1.814830  0.323169 -0.697165  0.059216 -0.763713 -2.021597
#
# ...

# %%
#Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

#Creating a df
realestate_df = pd.DataFrame({'Annualized Returns': annualized_returns})
realestate_df["Annualized Returns"] = realestate_df["Annualized Returns"].round(2)
realestate_df_sorted = realestate_df.sort_values(by = "Annualized Returns", ascending = False)
print(realestate_df_sorted)

# Visualize the holding period returns using a bar chart
realestate_df_sorted.plot(kind='bar', figsize=(10,10))
plt.title('Annualized Returns for Real Estate Stocks')
plt.ylabel('Return (%)')
plt.show()
# Out:
#       Annualized Returns
# VICI               13.72
# IRM                 1.90
# HST                -6.12
# O                  -6.92
# VTR               -10.03
# KIM               -10.63
# REG               -14.58
# PSA               -18.31
# WY                -19.39
# EQIX              -20.36
# WELL              -21.14
# SPG               -22.33
# FRT               -23.06
# AMT               -24.26
# SBAC              -25.74
# PEAK              -27.81
# MAA               -28.93
# CBRE              -29.39
# PLD               -30.10
# EXR               -30.74
# ARE               -31.89
# CCI               -32.48
# INVH              -32.72
# EQR               -33.11
# UDR               -33.57
# AVB               -34.17
# CPT               -35.01
# ESS               -38.31
# DLR               -40.68
# BXP               -41.29

# %% [markdown]
# # Annualized Returns for the Consumer Discretionary stocks in descending order

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ['AAP', 'AMZN', 'APTV', 'AZO', 'BBWI', 'BBY', 'BKNG', 'BWA', 'CCL', 'CMG', 'CZR', 'DHI', 'DPZ', 'DRI', 'EBAY', 'ETSY', 'EXPE', 'F', 'GM', 'GPC', 'GRMN', 'HAS', 'HD', 'HLT', 'KMX', 'LEN', 'LKQ', 'LOW', 'LVS', 'MAR', 'MCD', 'MGM', 'MHK', 'NCLH', 'NKE', 'NVR', 'NWL', 'ORLY', 'PHM', 'POOL', 'RCL', 'RL', 'ROST', 'SBUX', 'TJX', 'TPR', 'TSCO', 'TSLA', 'ULTA', 'VFC', 'WHR', 'WYNN', 'YUM']
start_date = '2022-01-01'
end_date = '2022-12-31'


# Getting the price data from yahoo 
consumerdiscretionary_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(consumerdiscretionary_adj_close / consumerdiscretionary_adj_close.shift(1))
print(log_returns*100)
# Out:
# [*********************100%***********************]  53 of 53 completed
#                  AAP      AMZN      APTV       AZO      BBWI       BBY  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04  0.113967 -1.706029  3.654621  1.703651  1.185145  2.914412
# 2022-01-05 -0.253433 -1.907385 -2.308545 -2.246902 -5.619876 -2.056376
# 2022-01-06  2.175358 -0.673360  3.411544  1.389492 -6.610127 -0.116581
# 2022-01-07 -1.484156 -0.429700 -2.706876 -2.340893 -3.992674 -0.370049
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23  0.841037  1.727444  0.285309  1.108285  3.889646  1.100066
# 2022-12-27  1.207102 -2.626569  0.262637  0.969109  0.023847  0.624964
# 2022-12-28  0.192888 -1.480072 -1.342303  0.297392 -2.902261 -2.086107
# 2022-12-29  0.692708  2.843566  3.835550  0.111652  2.184550  1.325836
# 2022-12-30  0.490892 -0.214057 -0.727510  0.073016  1.169600 -1.275953
#
# ...

# %%
#Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

#Creating a df
consumerdiscretionary_df = pd.DataFrame({'Annualized Returns': annualized_returns})
consumerdiscretionary_df["Annualized Returns"] = consumerdiscretionary_df["Annualized Returns"].round(2)
consumerdiscretionary_df_sorted = consumerdiscretionary_df.sort_values(by = "Annualized Returns", ascending = False)
print(consumerdiscretionary_df_sorted)

# Visualize the holding period returns using a bar chart
consumerdiscretionary_df_sorted.plot(kind='bar', figsize=(10,10))
plt.title('Annualized Returns for Consumer Discretionary Stocks')
plt.ylabel('Return (%)')
plt.show()
# Out:
#       Annualized Returns
# GPC                29.15
# LVS                23.93
# ORLY               21.46
# AZO                20.76
# ULTA               13.62
# TJX                 7.31
# ROST                3.99
# MCD                 0.32
# TSCO               -2.82
# DRI                -3.68
# TPR                -3.84
# YUM                -4.42
# WYNN               -6.09
# LKQ                -7.10
# MAR                -8.67
# BWA                -9.47
# RL                -10.05
# SBUX              -13.06
# DHI               -14.42
# LEN               -17.69
# PHM               -17.82
# BBY               -18.05
# HLT               -18.06
# CMG               -18.07
# BKNG              -18.26
# NVR               -20.03
# LOW               -20.73
# HD                -20.92
# MGM               -26.44
# NKE               -28.39
# GRMN              -29.04
# AAP               -35.92
# DPZ               -36.89
# WHR               -36.89
# EBAY              -37.01
# NWL               -38.05
# ...

# %% [markdown]
# # Top 3 performing stocks of Energy sector-Statistical Analysis & Comparison with S&P500 (Barchart)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ["OXY","HES","MPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Download historical price data for each stock
prices = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Create a new dataframe to hold the holding period returns
df = pd.DataFrame()

# Calculating the daily log returns for each stock and add it to the dataframe
for ticker in tickers:
    df[ticker + '_Log_Returns'] = np.log(prices[ticker]/prices[ticker].shift(1))

mean = df[['OXY_Log_Returns', 'HES_Log_Returns', 'MPC_Log_Returns']].mean()
std = df[['OXY_Log_Returns', 'HES_Log_Returns', 'MPC_Log_Returns']].std()
var = df[['OXY_Log_Returns', 'HES_Log_Returns', 'MPC_Log_Returns']].var()
max = df[['OXY_Log_Returns', 'HES_Log_Returns', 'MPC_Log_Returns']].max()
min = df[['OXY_Log_Returns', 'HES_Log_Returns', 'MPC_Log_Returns']].min()

print("Mean:")
print(mean*100)

print("Standard deviation:")
print(std*100)

print("Variance:")
print(var*100)

print("Maximum:")
print(max*100)

print("Minimum:")
print(min*100)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Mean:
# OXY_Log_Returns    0.286152
# HES_Log_Returns    0.250479
# MPC_Log_Returns    0.239263
# dtype: float64
# Standard deviation:
# OXY_Log_Returns    3.425206
# HES_Log_Returns    2.823977
# MPC_Log_Returns    2.282090
# dtype: float64
# Variance:
# OXY_Log_Returns    0.117320
# HES_Log_Returns    0.079748
# MPC_Log_Returns    0.052079
# dtype: float64
# Maximum:
# OXY_Log_Returns    16.204751
# HES_Log_Returns     6.920700
# MPC_Log_Returns     7.508441
# dtype: float64
# Minimum:
# OXY_Log_Returns   -11.578320
# HES_Log_Returns    -9.400605
# MPC_Log_Returns    -7.253806
# dtype: float64

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["OXY", "HES", "MPC", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
energy_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(energy_adj_close / energy_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# # Top 3 Real Estate stocks-Statistical Analysis & Comparison with S&P500 in (Barchart)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ["VICI","IRM","HST"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Download historical price data for each stock
prices = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Create a new dataframe to hold the holding period returns
df = pd.DataFrame()

# Calculating the daily log returns for each stock and add it to the dataframe
for ticker in tickers:
    df[ticker + '_Log_Returns'] = np.log(prices[ticker]/prices[ticker].shift(1))

mean = df[['VICI_Log_Returns', 'IRM_Log_Returns', 'HST_Log_Returns']].mean()
std = df[['VICI_Log_Returns', 'IRM_Log_Returns', 'HST_Log_Returns']].std()
var = df[['VICI_Log_Returns', 'IRM_Log_Returns', 'HST_Log_Returns']].var()
max = df[['VICI_Log_Returns', 'IRM_Log_Returns', 'HST_Log_Returns']].max()
min = df[['VICI_Log_Returns', 'IRM_Log_Returns', 'HST_Log_Returns']].min()

print("Mean:")
print(mean*100)

print("Standard deviation:")
print(std*100)

print("Variance:")
print(var*100)

print("Maximum:")
print(max*100)

print("Minimum:")
print(min*100)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Mean:
# VICI_Log_Returns    0.051050
# IRM_Log_Returns     0.007485
# HST_Log_Returns    -0.025066
# dtype: float64
# Standard deviation:
# VICI_Log_Returns    1.683557
# IRM_Log_Returns     2.219938
# HST_Log_Returns     2.504677
# dtype: float64
# Variance:
# VICI_Log_Returns    0.028344
# IRM_Log_Returns     0.049281
# HST_Log_Returns     0.062734
# dtype: float64
# Maximum:
# VICI_Log_Returns    4.594006
# IRM_Log_Returns     7.280506
# HST_Log_Returns     7.809895
# dtype: float64
# Minimum:
# VICI_Log_Returns    -5.911292
# IRM_Log_Returns    -10.362154
# HST_Log_Returns     -8.447848
# dtype: float64

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["VICI", "IRM", "HST", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
realestate_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(realestate_adj_close / realestate_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %% [markdown]
# # 3 Best Consumer Discretionary stocks-Statistical Analysis and Comparison with S&P 500 (Barchart)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define the list of tickers
tickers = ["GPC","LVS","ORLY"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Download historical price data for each stock
prices = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Create a new dataframe to hold the holding period returns
df = pd.DataFrame()

# Calculating the daily log returns for each stock and add it to the dataframe
for ticker in tickers:
    df[ticker + '_Log_Returns'] = np.log(prices[ticker]/prices[ticker].shift(1))

mean = df[['GPC_Log_Returns', 'LVS_Log_Returns', 'ORLY_Log_Returns']].mean()
std = df[['GPC_Log_Returns', 'LVS_Log_Returns', 'ORLY_Log_Returns']].std()
var = df[['GPC_Log_Returns', 'LVS_Log_Returns', 'ORLY_Log_Returns']].var()
max = df[['GPC_Log_Returns', 'LVS_Log_Returns', 'ORLY_Log_Returns']].max()
min = df[['GPC_Log_Returns', 'LVS_Log_Returns', 'ORLY_Log_Returns']].min()

print("Mean:")
print(mean*100)

print("Standard deviation:")
print(std*100)

print("Variance:")
print(var*100)

print("Maximum:")
print(max*100)

print("Minimum:")
print(min*100)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Mean:
# GPC_Log_Returns     0.101575
# LVS_Log_Returns     0.085180
# ORLY_Log_Returns    0.077170
# dtype: float64
# Standard deviation:
# GPC_Log_Returns     1.542473
# LVS_Log_Returns     3.577376
# ORLY_Log_Returns    1.876860
# dtype: float64
# Variance:
# GPC_Log_Returns     0.023792
# LVS_Log_Returns     0.127976
# ORLY_Log_Returns    0.035226
# dtype: float64
# Maximum:
# GPC_Log_Returns      4.927395
# LVS_Log_Returns     14.030999
# ORLY_Log_Returns     4.897846
# dtype: float64
# Minimum:
# GPC_Log_Returns     -4.556894
# LVS_Log_Returns    -12.657356
# ORLY_Log_Returns   -13.489214
# dtype: float64

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["GPC","LVS","ORLY", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
consumerdiscretionary_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(consumerdiscretionary_adj_close / consumerdiscretionary_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)
print(sorted_returns)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  4 of 4 completed
# GPC      29.154540
# LVS      23.931954
# ORLY     21.457354
# ^GSPC   -20.103427
# dtype: float64

# %% [markdown]
# # Statistical Analysis of Energy Sector & Annualized Return Comparison with S&P500 (Barchart)

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the list of 50 stocks
stock_list = ['APA', 'BKR', 'COP', 'CTRA', 'CVX', 'DVN', 'EOG', 'EQT', 'FANG', 'HAL', 'HES', 'KMI', 'MPC', 'MRO', 'OKE', 'OXY', 'PSX', 'PXD', 'SLB', 'TRGP', 'VLO', 'WMB', 'XOM']

# Download historical prices for each stock over the holding period
energy_adj_close = yf.download(stock_list, start='2022-01-01', end='2022-12-31')['Adj Close']

# Calculating the daily log returns for each stock
log_returns = np.log(energy_adj_close / energy_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Combine the daily returns of all stocks into a single DataFrame
annualized_returns['Energy'] = log_returns.mean(axis=1)

# Calculate the mean and standard deviation of the daily returns of the group
mean = annualized_returns['Energy'].mean()
std = annualized_returns['Energy'].std()
var = annualized_returns['Energy'].var()
max = annualized_returns['Energy'].max()
min = annualized_returns['Energy'].min()

print(f"Mean return of the Energy: {mean:.4f}")
print(f"Standard deviation of the Energy: {std:.4f}")
print(f"Variance of the Energy: {var:.4f}")
print(f"Max of the Energy: {max:.4f}")
print(f"Min of the Energy: {min:.4f}")
# Out:
# [*********************100%***********************]  23 of 23 completed
# Mean return of the Energy: 0.0017
# Standard deviation of the Energy: 0.0240
# Variance of the Energy: 0.0006
# Max of the Energy: 0.0568
# Min of the Energy: -0.0960

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["XLE", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
energy_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(energy_adj_close / energy_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# # Statistical Analysis of Real Estate & Annualized Comparison with S&P500 (Barchart)

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the list of 50 stocks
stock_list = ['AMT', 'ARE', 'AVB', 'BXP', 'CBRE', 'CCI', 'CPT', 'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'HST', 'INVH', 'IRM', 'KIM', 'MAA', 'O', 'PEAK', 'PLD', 'PSA', 'REG', 'SBAC', 'SPG', 'UDR', 'VICI', 'VTR', 'WELL', 'WY']

# Download historical prices for each stock over the holding period
realestate_adj_close = yf.download(stock_list, start='2022-01-01', end='2022-12-31')['Adj Close']

# Calculating the daily log returns for each stock
log_returns = np.log(realestate_adj_close / realestate_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Combine the daily returns of all stocks into a single DataFrame
annualized_returns['Real Estate'] = log_returns.mean(axis=1)

# Calculate the mean and standard deviation of the daily returns of the group
mean = annualized_returns['Real Estate'].mean()
std = annualized_returns['Real Estate'].std()
var = annualized_returns['Real Estate'].var()
max = annualized_returns['Real Estate'].max()
min = annualized_returns['Real Estate'].min()

print(f"Mean return of the Real Estate: {mean:.4f}")
print(f"Standard deviation of the Real Estate: {std:.4f}")
print(f"Variance of the Real Estate: {var:.4f}")
print(f"Max of the Real Estate: {max:.4f}")
print(f"Min of the Real Estate: {min:.4f}")
# Out:
# [*********************100%***********************]  30 of 30 completed
# Mean return of the Real Estate: -0.0011
# Standard deviation of the Real Estate: 0.0156
# Variance of the Real Estate: 0.0002
# Max of the Real Estate: 0.0710
# Min of the Real Estate: -0.0522

# %%
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["XLRE", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
realestate_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(realestate_adj_close / realestate_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# # Statistical Analysis of Consumer Discretionary & Annualized Return Comparison with S&P 500 (Barchart)

# %%
import pandas as pd
import numpy as np
import yfinance as yf

# Define the list of 50 stocks
stock_list = ['AAP', 'AMZN', 'APTV', 'AZO', 'BBWI', 'BBY', 'BKNG', 'BWA', 'CCL', 'CMG', 'CZR', 'DHI', 'DPZ', 'DRI', 'EBAY', 'ETSY', 'EXPE', 'F', 'GM', 'GPC', 'GRMN', 'HAS', 'HD', 'HLT', 'KMX', 'LEN', 'LKQ', 'LOW', 'LVS', 'MAR', 'MCD', 'MGM', 'MHK', 'NCLH', 'NKE', 'NVR', 'NWL', 'ORLY', 'PHM', 'POOL', 'RCL', 'RL', 'ROST', 'SBUX', 'TJX', 'TPR', 'TSCO', 'TSLA', 'ULTA', 'VFC', 'WHR', 'WYNN', 'YUM']

# Download historical prices for each stock over the holding period
consumerdiscretionary_adj_close = yf.download(stock_list, start='2022-01-01', end='2022-12-31')['Adj Close']

# Calculating the daily log returns for each stock
log_returns = np.log(consumerdiscretionary_adj_close / consumerdiscretionary_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Combine the daily returns of all stocks into a single DataFrame
annualized_returns['Consumer Discretionary'] = log_returns.mean(axis=1)

# Calculate the mean and standard deviation of the daily returns of the group
mean = annualized_returns['Consumer Discretionary'].mean()
std = annualized_returns['Consumer Discretionary'].std()
var = annualized_returns['Consumer Discretionary'].var()
max = annualized_returns['Consumer Discretionary'].max()
min = annualized_returns['Consumer Discretionary'].min()

print(f"Mean return of the Consumer Discretionary: {mean:.4f}")
print(f"Standard deviation of the Consumer Discretionary: {std:.4f}")
print(f"Variance of the Consumer Discretionary: {var:.4f}")
print(f"Max of the Consumer Discretionary: {max:.4f}")
print(f"Min of the Consumer Discretionary: {min:.4f}")
# Out:
# [*********************100%***********************]  53 of 53 completed
# Mean return of the Consumer Discretionary: -0.0012
# Standard deviation of the Consumer Discretionary: 0.0205
# Variance of the Consumer Discretionary: 0.0004
# Max of the Consumer Discretionary: 0.0713
# Min of the Consumer Discretionary: -0.0630

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Define the tickers and the start and end dates
tickers = ["XLY", "^GSPC"]
start_date = '2022-01-01'
end_date = '2022-12-31'

# Getting the price data from yahoo 
consumerdiscretionary_adj_close = yf.download(tickers, start=start_date, end=end_date)["Adj Close"]

# Calculating the daily log returns for each stock
log_returns = np.log(consumerdiscretionary_adj_close / consumerdiscretionary_adj_close.shift(1))

# Calculate annual log-return
annualized_returns = ((1 + log_returns.mean()) ** 252 - 1)*100

# Sort the returns in descending order
sorted_returns = annualized_returns.sort_values(ascending=False)

# Create the bar chart
fig, ax = plt.subplots(figsize=(8,6))
sorted_returns.plot(kind='bar', ax=ax)

# Add labels and title
ax.set_xlabel('Stock Ticker')
ax.set_ylabel('Annualized Return')
ax.set_title('Annualized Return Comparison with S&P500')

# Show the chart
plt.show()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# # Daily Returns of S&P500 Sectors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

sector_tickers = ['^GSPC', 'XLC', 'XLY', 'XLP', 'XLE', 'XLF', 'XLV', 'XLI', 'XLB', 'XLRE', 'XLK', 'XLU']
sector_data = yf.download(sector_tickers, start="2022-01-01", end="2022-12-31")['Adj Close']
sector_returns = sector_data.pct_change()*100

plt.figure(figsize=(10, 5))
plt.plot(sector_returns)
plt.legend(sector_returns.columns)
plt.title('Daily Returns of S&P500 Sectors')
plt.xlabel('Time Period')
plt.ylabel('Daily Returns-Percentage %')
plt.show()
# Out:
# [*********************100%***********************]  12 of 12 completed

# %% [markdown]
# # Correlation Performance of S&P 500 sectors in 2022

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot as plt

# Define S&P500 sectors
sectors = {
    'S&P500': ['^GSPC'],
    'Communication Services': ['XLC'],
    'Consumer Discretionary': ['XLY'],
    'Consumer Staples': ['XLP'],
    'Energy': ['XLE'],
    'Financials': ['XLF'],
    'Health Care': ['XLV'],
    'Industrials': ['XLI'],
    'Information Technology': ['XLK'],
    'Materials': ['XLB'],
    'Real Estate': ['XLRE'],
    'Utilities': ['XLU']
}

# Download historical data for S&P500 stocks
data = yf.download(list(np.concatenate(list(sectors.values()))), start='2022-01-01')['Adj Close']

# Calculate daily returns
returns = data.pct_change()

# Calculate correlation matrix
corr_matrix = returns.corr()

# Plot correlation matrix
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('S&P500 Correlation Matrix')
plt.show()
plt.savefig("S&P500 Correlation Matrix.pdf")
# Out:
# [*********************100%***********************]  12 of 12 completed

# %% [markdown]
# # Comparison of Annualized Return of S&P 500 and its Sectors

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Define tickers and sector ETFs
tickers = ['^GSPC', 'XLC', 'XLY', 'XLP', 'XLE', 'XLF', 'XLV', 'XLI', 'XLB', 'XLRE', 'XLK', 'XLU']
sectors = ['S&P500', 'Consumer Discretionary', 'Consumer Staples', 'Energy',
           'Financials', 'Health Care', 'Industrials', 'Materials', 'Real Estate', 'Technology', 'Utilities']

# Download historical data for each ticker
data = pd.DataFrame()
for ticker in tickers:
    try:
        ticker_data = yf.download(ticker, start='2022-01-01', end='2022-12-31')['Adj Close']
        ticker_data.name = ticker
        data = pd.concat([data, ticker_data], axis=1)
    except KeyError:
        print(f"'{ticker}' data not found")

# Calculate daily returns and annualize them
returns = data.pct_change()
annualized_returns = ((1 + returns.mean()) ** 252 - 1) * 100

# Create a DataFrame of annualized returns for each sector
sector_returns = pd.DataFrame({'Sector': sectors, 'Return': [annualized_returns[tickers[i]] for i in range(len(sectors))]})
sector_returns = sector_returns.sort_values('Return', ascending=False).reset_index(drop=True)

# Set the color for positive and negative annualized returns
positive_color = 'green'
negative_color = 'red'

# Plot the holding period return of each sector and the index in a bar chart
plt.figure(figsize=(12,6))
plt.bar(sector_returns['Sector'], sector_returns['Return'], color=[positive_color if r >= 0 else negative_color for r in sector_returns['Return']])
plt.axhline(y=0, color='black', linestyle='-')
plt.title('Annualized Return of S&P 500 and Its Sectors', fontsize=16)
plt.xlabel('Sector', fontsize=14)
plt.ylabel('Annualized Return (%)', fontsize=14)
plt.xticks(rotation=90)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
